# %% [markdown]
# # Case3-challenge00

# %% [markdown]
# At first, we add the analysis directory to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# At first, we load the data, 'case3_chalenge_00.txt'.

# %%
import astropy.io.ascii as asc
from astropy import units as u

data = asc.read('case3_challenge_00.txt')
data['x'].unit = u.um
data['y'].unit = u.um
data['ra'].unit = u.deg
data['dec'].unit = u.deg

# %% [markdown]
# The source distribution is shown in the figure below.

# %%
import matplotlib.pylab as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot(111)
ax.scatter(data['x'], data['y'], marker='x')
ax.set_xlabel('X (um)')
ax.set_ylabel('Y (um)')
ax.set_xlim([-25000,25000])
ax.set_ylim([-25000,25000])
ax.set_aspect('equal', adjustable='box')

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot(111)
ax.scatter(data['ra'], data['dec'], marker='x')
ax.scatter(data['ra']-360.0, data['dec'], marker='x')
ax.set_xlabel('R.A. (deg)')
ax.set_ylabel('Dec. (deg)')
ax.set_xlim([-0.3,0.3])
ax.set_aspect('equal', adjustable='box')

# %% [markdown]
# We guess the astrometric(?) parameters.

# %%
import numpy as np
from astropy.coordinates import SkyCoord, Angle

r = np.sqrt(data['x']**2.+data['y']**2.)
i0 = np.argmin(r)
ra0  = data['ra'].quantity[i0]
dec0 = data['dec'].quantity[i0]

c0 = SkyCoord(ra=ra0, dec=dec0, frame='icrs')
c1 = SkyCoord(ra=data['ra'].quantity[0], dec=data['dec'].quantity[0], frame='icrs')
angle_sep = c0.separation(c1)

dx = data['x'].quantity[i0] - data['x'].quantity[0]
dy = data['y'].quantity[i0] - data['y'].quantity[0]
um_sep = np.sqrt(dx*dx+dy*dy)

scale0 = angle_sep/um_sep

pa0 = 0.0 * u.deg

print(ra0)
print(dec0)
print(scale0)
print(pa0)
# Out:
# 0.006122448979591855 deg
# 0.006122448979591855 deg
# 7.5505568676706854e-06 deg / um
# 0.0 deg

# %% [markdown]
# We define a model function which calculates RA and Dec from the position on the focal plane. In this example, we consider the focal-plane distortion. It is represented by the Sip function implemented to astropy.wcs.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip

def wcs(ra0, dec0, pa0, scale0, a, b):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale0, scale0])
    w.wcs.crval=[ra0, dec0]
    w.wcs.ctype=["RA---TAN", "DEC--TAN"]
    w.wcs.pc=[[ np.cos(pa0*u.deg), np.sin(pa0*u.deg)],
              [-np.sin(pa0*u.deg), np.cos(pa0*u.deg)]]
    w.sip = Sip(a, b, None, None, [0, 0])
    return w

# %%
def model(params, pxcrd, sip_order):
    # params must be an array of dimension-less values.
    ra_ptg  = params[0] # value in deg.
    dec_ptg = params[1] # value in deg.
    pa_ptg  = params[2] # value in deg.
    scale   = params[3] # value in deg/um.
    a = np.zeros(shape=(sip_order+1, sip_order+1))
    b = np.zeros(shape=(sip_order+1, sip_order+1))
    for m in range(0, sip_order+1):
        n = sip_order - m
        a[m, n] = params[4+m]
        b[m, n] = params[4+m+sip_order+1]
    
    w = wcs(ra_ptg, dec_ptg, pa_ptg, scale, a, b)
    world = w.all_pix2world(pixcrd, 0)

    # constraining ra and dec in 'world' between -180 to 180 deg.
    pos = np.where(world>180.)
    world[pos] = world[pos] - 360.
    pos = np.where(world<-180.)
    world[pos] = world[pos] + 360.
    
    return world.T.flatten()

# %% [markdown]
# Then, we make an array of the coordinates on the focal plane.

# %%
pixcrd = np.concatenate(([data['x']],[data['y']])).T

# %% [markdown]
# And now, we estimate the field and distortion parameters with the LeastSquare module. Here, we set the sip order to be 3.

# %%
from common.leastsquare import LeastSquare

sip_order = 3

ls = LeastSquare(lambda a: model(a, pixcrd, sip_order), np.size(data['x'])*2)

# constructing a_init (initial parameter set).
a_init = [ra0.value, dec0.value, pa0.value, scale0.value]
for i in range(0, 2*(sip_order+1)):
    a_init.append(0)
a_init = np.array(a_init) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
true_pos = np.concatenate((data['ra'], data['dec']))
pos = np.where(true_pos>180.)
true_pos[pos] = true_pos[pos] - 360.
pos = np.where(true_pos<-180.)
true_pos[pos] = true_pos[pos] + 360.

result, _ = ls.solve(true_pos, a_init, max_iteration=100)

if result[3] < 0:
    result[3] = -result[3]
    result[2] = result[2] + 180.0

if result[2] > 360.0 or result[2] < 0.0:
    result[2] = result[2]%360.0
# Out:
# 2021-07-07 10:57:58,550  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 42.645742)
# 2021-07-07 10:57:58,571  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 81.201303)
# 2021-07-07 10:57:58,591  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 173.054192)
# 2021-07-07 10:57:58,612  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 13.750405)
# 2021-07-07 10:57:58,633  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 26.642260)
# 2021-07-07 10:57:58,653  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 2.910286)
# 2021-07-07 10:57:58,673  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 3.408701)
# 2021-07-07 10:57:58,694  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 1.545484)
# 2021-07-07 10:57:58,714  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.538341)
# 2021-07-07 10:57:58,735  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.202903)
# 2021-07-07 10:57:58,755  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.074036)
# 2021-07-07 10:57:58,776  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.027568)
# 2021-07-07 10:57:58,796  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.010243)
# 2021-07-07 10:57:58,817  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.003822)
# 2021-07-07 10:57:58,837  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.001425)
# 2021-07-07 10:57:58,858  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000531)
# 2021-07-07 10:57:58,878  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000199)
# 2021-07-07 10:57:58,898  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.000074)
# 2021-07-07 10:57:58,918  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000029)
# 2021-07-07 10:57:58,939  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000012)
# 2021-07-07 10:57:58,959  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000006)
# 2021-07-07 10:57:58,979  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.000002)
# 2021-07-07 10:57:58,999  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000002)
# 2021-07-07 10:57:59,020  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000002)
# 2021-07-07 10:57:59,040  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000001)
# 2021-07-07 10:57:59,061  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.000001)
# 2021-07-07 10:57:59,082  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000000)
# 2021-07-07 10:57:59,102  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.000000)
# 2021-07-07 10:57:59,122  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.000001)
# 2021-07-07 10:57:59,142  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.000002)
# 2021-07-07 10:57:59,162  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000000)
# 2021-07-07 10:57:59,183  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000000)
# 2021-07-07 10:57:59,203  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000000)
# 2021-07-07 10:57:59,224  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000000)
# 2021-07-07 10:57:59,244  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000000)
# 2021-07-07 10:57:59,264  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000000)
# 2021-07-07 10:57:59,284  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000000)
# 2021-07-07 10:57:59,305  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000000)
# 2021-07-07 10:57:59,325  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000000)
# 2021-07-07 10:57:59,345  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000001)
# 2021-07-07 10:57:59,365  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.000003)
# 2021-07-07 10:57:59,386  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000001)
# 2021-07-07 10:57:59,406  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000000)
# 2021-07-07 10:57:59,427  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000001)
# 2021-07-07 10:57:59,447  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000001)
# 2021-07-07 10:57:59,467  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000002)
# 2021-07-07 10:57:59,487  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000000)
# 2021-07-07 10:57:59,508  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000000)
# 2021-07-07 10:57:59,528  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000000)
# 2021-07-07 10:57:59,548  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000001)
# 2021-07-07 10:57:59,569  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000001)
# 2021-07-07 10:57:59,589  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000001)
# 2021-07-07 10:57:59,609  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000001)
# 2021-07-07 10:57:59,629  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000001)
# 2021-07-07 10:57:59,649  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000000)
# 2021-07-07 10:57:59,670  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000000)
# 2021-07-07 10:57:59,690  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000000)
# 2021-07-07 10:57:59,710  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000002)
# 2021-07-07 10:57:59,730  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000001)
# 2021-07-07 10:57:59,750  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000001)
# 2021-07-07 10:57:59,771  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000001)
# 2021-07-07 10:57:59,791  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000001)
# 2021-07-07 10:57:59,810  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000000)
# 2021-07-07 10:57:59,830  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.000000)
# 2021-07-07 10:57:59,851  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.000001)
# 2021-07-07 10:57:59,871  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.000001)
# 2021-07-07 10:57:59,906  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.000002)
# 2021-07-07 10:57:59,926  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000001)
# 2021-07-07 10:57:59,947  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000002)
# 2021-07-07 10:57:59,967  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000001)
# 2021-07-07 10:57:59,988  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000001)
# 2021-07-07 10:58:00,008  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000000)
# 2021-07-07 10:58:00,028  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.000001)
# 2021-07-07 10:58:00,048  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000002)
# 2021-07-07 10:58:00,069  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.000001)
# 2021-07-07 10:58:00,089  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000001)
# 2021-07-07 10:58:00,109  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000000)
# 2021-07-07 10:58:00,129  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000001)
# 2021-07-07 10:58:00,149  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000001)
# 2021-07-07 10:58:00,169  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000001)
# 2021-07-07 10:58:00,189  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000001)
# 2021-07-07 10:58:00,210  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000001)
# 2021-07-07 10:58:00,230  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000001)
# 2021-07-07 10:58:00,250  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000002)
# 2021-07-07 10:58:00,270  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000002)
# 2021-07-07 10:58:00,290  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000002)
# 2021-07-07 10:58:00,310  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.000001)
# 2021-07-07 10:58:00,330  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000000)
# 2021-07-07 10:58:00,350  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000001)
# 2021-07-07 10:58:00,370  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000001)
# 2021-07-07 10:58:00,390  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000001)
# 2021-07-07 10:58:00,411  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000002)
# 2021-07-07 10:58:00,431  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.000002)
# 2021-07-07 10:58:00,451  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000000)
# 2021-07-07 10:58:00,471  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000001)
# 2021-07-07 10:58:00,491  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.000000)
# 2021-07-07 10:58:00,512  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000000)
# 2021-07-07 10:58:00,532  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000001)
# 2021-07-07 10:58:00,552  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000001)
# 2021-07-07 10:58:00,572  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000000)

# %% [markdown]
# The result is...

# %%
print("Center R.A.   : {:f} deg.".format(result[0]))
print("Center Dec.   : {:f} deg.".format(result[1]))
print("Position angle: {:f} deg.".format(result[2]))
print("Plate scale   : {:e} deg/um".format(result[3]))
# Out:
# Center R.A.   : 0.001330 deg.
# Center Dec.   : 0.002338 deg.
# Position angle: 134.840688 deg.
# Plate scale   : 7.923576e-06 deg/um

# %%
print(result[4:4+sip_order+1])
print(result[4+sip_order+1:])
# Out:
# [ 4.15788398e-14  2.49514065e-13  6.62583620e-12 -1.13052394e-11]
# [ 1.28021179e-12  6.74271558e-12 -7.48527131e-12  1.04523548e-12]

# %% [markdown]
# According to the meta part of the input file, the poiunting RA and Dec are 0.0 deg. The position angle is 134.8344427850505 deg. The calculation seems to correctly estimate these parameters.

# %% [markdown]
# Let's compare the ra/dec values calculated from the derived parameters with the true values.

# %%
positions = model(result, pixcrd, sip_order)
positions = positions.reshape((2,int(positions.size/2))).T

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot(111)
ax.scatter(data['ra'], data['dec'], marker='+', label='Truth')
ax.scatter(data['ra']-360., data['dec'], marker='+', label='')
ax.scatter(positions[:,0], positions[:,1], marker='x', label='Reproduced')
ax.set_xlabel('R.A. (deg)')
ax.set_ylabel('Dec. (deg)')
ax.set_xlim([-0.3,0.3])
#ax.set_aspect('equal', adjustable='box')
ax.legend()

# %% [markdown]
# This plot shows that the reproduced ra/dec values match the true values. (But we still confirm small differences between them.)

# %%
from astropy.coordinates import SkyCoord

c_calc = SkyCoord(positions[:,0]*u.deg, positions[:,1]*u.deg, frame='icrs')
c_true = SkyCoord(data['ra'], data['dec'], frame='icrs')
sep = c_calc.separation(c_true)

# %%
plt.plot(sep.arcsec, '.')
plt.xlabel('Index')
plt.ylabel('Position estimation error (arcsec)')
# Out:
# Text(0, 0.5, 'Position estimation error (arcsec)')

# %% [markdown]
# The above plot shows that the typical positional differences between the reproduced positions and the true positions are around 1 arcsec. It seems to be too large. Higher-order polynomial functions might be needed to represent the distortion in this problem.
