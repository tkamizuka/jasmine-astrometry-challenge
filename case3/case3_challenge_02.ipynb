# %% [markdown]
# # Case3-challenge02

# %% [markdown]
# At first, we add the analysis directory to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# At first, we load the data, 'case3_chalenge_02.txt'.

# %%
import astropy.io.ascii as asc
from astropy import units as u

data = asc.read('case3_challenge_02.txt')
data['x'].unit = u.um
data['y'].unit = u.um
data['ra'].unit = u.deg
data['dec'].unit = u.deg

# %% [markdown]
# The source distribution is shown in the figure below.

# %%
import matplotlib.pylab as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot(111)
ax.scatter(data['x'], data['y'], marker='x')
ax.set_xlabel('X (um)')
ax.set_ylabel('Y (um)')
ax.set_xlim([-25000,25000])
ax.set_ylim([-25000,25000])
ax.set_aspect('equal', adjustable='box')

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot(111)
ax.scatter(data['ra'], data['dec'], marker='x')
ax.scatter(data['ra']-360.0, data['dec'], marker='x')
ax.set_xlabel('R.A. (deg)')
ax.set_ylabel('Dec. (deg)')
ax.set_xlim([-0.3,0.3])
ax.set_aspect('equal', adjustable='box')

# %% [markdown]
# We guess the astrometric(?) parameters.

# %%
import numpy as np
from astropy.coordinates import SkyCoord, Angle

r = np.sqrt(data['x']**2.+data['y']**2.)
i0 = np.argmin(r)
ra0  = data['ra'].quantity[i0]
dec0 = data['dec'].quantity[i0]

c0 = SkyCoord(ra=ra0, dec=dec0, frame='icrs')
c1 = SkyCoord(ra=data['ra'].quantity[0], dec=data['dec'].quantity[0], frame='icrs')
angle_sep = c0.separation(c1)

dx = data['x'].quantity[i0] - data['x'].quantity[0]
dy = data['y'].quantity[i0] - data['y'].quantity[0]
um_sep = np.sqrt(dx*dx+dy*dy)

scale0 = angle_sep/um_sep

pa0 = 0.0 * u.deg

print(ra0)
print(dec0)
print(scale0)
print(pa0)
# Out:
# 0.006122448979591855 deg
# -0.006122448979591855 deg
# 8.6568474155809e-06 deg / um
# 0.0 deg

# %% [markdown]
# We define a model function which calculates RA and Dec from the position on the focal plane. In this example, we consider the focal-plane distortion. It is represented by the Sip function implemented to astropy.wcs. Here, we set the order of the polynomial functions to be 2.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip

def wcs(ra0, dec0, pa0, scale0, a, b):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale0, scale0])
    w.wcs.crval=[ra0, dec0]
    w.wcs.ctype=["RA---TAN", "DEC--TAN"]
    w.wcs.pc=[[ np.cos(pa0*u.deg), np.sin(pa0*u.deg)],
              [-np.sin(pa0*u.deg), np.cos(pa0*u.deg)]]
    w.sip = Sip(a, b, None, None, [0, 0])
    return w

# %%
def model(params, pxcrd):
    ra_ptg  = params[0] # value in deg.
    dec_ptg = params[1] # value in deg.
    pa_ptg  = params[2] # value in deg.
    scale   = params[3] # value in deg/um.
    a = np.array([[0, 0, params[4]], [0, params[5], 0], [params[6], 0, 0]])
    b = np.array([[0, 0, params[7]], [0, params[8], 0], [params[9], 0, 0]])
    # params must be an array of dimension-less values.
    
    w = wcs(ra_ptg, dec_ptg, pa_ptg, scale, a, b)
    world = w.all_pix2world(pixcrd, 0)

    # constraining ra and dec in 'world' between -180 to 180 deg.
    pos = np.where(world>180.)
    world[pos] = world[pos] - 360.
    pos = np.where(world<-180.)
    world[pos] = world[pos] + 360.
    
    return world.T.flatten()

# %% [markdown]
# Then, we make an array of the coordinates on the focal plane.

# %%
pixcrd = np.concatenate(([data['x']],[data['y']])).T

# %% [markdown]
# And now, we estimate the astrometric(?) parameters with the LeastSquare module.

# %%
from common.leastsquare import LeastSquare

ls = LeastSquare(lambda a: model(a, pixcrd), np.size(data['x'])*2)

a_init = np.array([ra0.value, dec0.value, pa0.value, scale0.value, 0, 0, 0, 0, 0, 0]) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
true_pos = np.concatenate((data['ra'], data['dec']))
pos = np.where(true_pos>180.)
true_pos[pos] = true_pos[pos] - 360.
pos = np.where(true_pos<-180.)
true_pos[pos] = true_pos[pos] + 360.

result, _ = ls.solve(true_pos, a_init, max_iteration=100)

if result[3] < 0:
    result[3] = -result[3]
    result[2] = result[2] + 180.0

if result[2] > 360.0 or result[2] < 0.0:
    result[2] = result[2]%360.0
# Out:
# 2021-07-06 22:41:24,892  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 34.547198)
# 2021-07-06 22:41:24,910  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 72.462794)
# 2021-07-06 22:41:24,931  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 8.965022)
# 2021-07-06 22:41:24,948  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 6.606508)
# 2021-07-06 22:41:24,966  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 0.009230)
# 2021-07-06 22:41:24,984  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 0.000062)
# 2021-07-06 22:41:25,001  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 0.000000)
# 2021-07-06 22:41:25,019  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 0.000000)
# 2021-07-06 22:41:25,037  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.000000)
# 2021-07-06 22:41:25,055  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.000000)
# 2021-07-06 22:41:25,072  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.000000)
# 2021-07-06 22:41:25,090  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.000000)
# 2021-07-06 22:41:25,108  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.000000)
# 2021-07-06 22:41:25,126  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.000000)
# 2021-07-06 22:41:25,144  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.000000)
# 2021-07-06 22:41:25,162  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000000)
# 2021-07-06 22:41:25,180  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000000)
# 2021-07-06 22:41:25,198  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.000000)
# 2021-07-06 22:41:25,215  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000000)
# 2021-07-06 22:41:25,233  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000000)
# 2021-07-06 22:41:25,251  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000000)
# 2021-07-06 22:41:25,269  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.000000)
# 2021-07-06 22:41:25,287  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000000)
# 2021-07-06 22:41:25,304  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000000)
# 2021-07-06 22:41:25,322  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000000)
# 2021-07-06 22:41:25,340  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.000000)
# 2021-07-06 22:41:25,358  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000000)
# 2021-07-06 22:41:25,375  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.000000)
# 2021-07-06 22:41:25,393  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.000000)
# 2021-07-06 22:41:25,411  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.000000)
# 2021-07-06 22:41:25,429  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000000)
# 2021-07-06 22:41:25,447  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000000)
# 2021-07-06 22:41:25,465  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000000)
# 2021-07-06 22:41:25,483  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000000)
# 2021-07-06 22:41:25,501  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000000)
# 2021-07-06 22:41:25,518  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000000)
# 2021-07-06 22:41:25,536  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000000)
# 2021-07-06 22:41:25,554  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000000)
# 2021-07-06 22:41:25,572  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000000)
# 2021-07-06 22:41:25,589  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000000)
# 2021-07-06 22:41:25,607  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.000000)
# 2021-07-06 22:41:25,625  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000000)
# 2021-07-06 22:41:25,643  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000000)
# 2021-07-06 22:41:25,660  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000000)
# 2021-07-06 22:41:25,678  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000000)
# 2021-07-06 22:41:25,696  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000000)
# 2021-07-06 22:41:25,714  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000000)
# 2021-07-06 22:41:25,732  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000000)
# 2021-07-06 22:41:25,750  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000000)
# 2021-07-06 22:41:25,768  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000000)
# 2021-07-06 22:41:25,786  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000000)
# 2021-07-06 22:41:25,804  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000000)
# 2021-07-06 22:41:25,821  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000000)
# 2021-07-06 22:41:25,839  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000000)
# 2021-07-06 22:41:25,857  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000000)
# 2021-07-06 22:41:25,875  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000000)
# 2021-07-06 22:41:25,893  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000000)
# 2021-07-06 22:41:25,911  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000000)
# 2021-07-06 22:41:25,929  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000000)
# 2021-07-06 22:41:25,947  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000000)
# 2021-07-06 22:41:25,965  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000000)
# 2021-07-06 22:41:25,983  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000000)
# 2021-07-06 22:41:26,001  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000000)
# 2021-07-06 22:41:26,018  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.000000)
# 2021-07-06 22:41:26,036  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.000000)
# 2021-07-06 22:41:26,054  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.000000)
# 2021-07-06 22:41:26,072  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.000000)
# 2021-07-06 22:41:26,090  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000000)
# 2021-07-06 22:41:26,107  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000000)
# 2021-07-06 22:41:26,125  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000000)
# 2021-07-06 22:41:26,143  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000000)
# 2021-07-06 22:41:26,161  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000000)
# 2021-07-06 22:41:26,179  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.000000)
# 2021-07-06 22:41:26,197  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000000)
# 2021-07-06 22:41:26,214  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.000000)
# 2021-07-06 22:41:26,232  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000000)
# 2021-07-06 22:41:26,250  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000000)
# 2021-07-06 22:41:26,268  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000000)
# 2021-07-06 22:41:26,286  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000000)
# 2021-07-06 22:41:26,304  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000000)
# 2021-07-06 22:41:26,321  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000000)
# 2021-07-06 22:41:26,339  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000000)
# 2021-07-06 22:41:26,357  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000000)
# 2021-07-06 22:41:26,375  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000000)
# 2021-07-06 22:41:26,393  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000000)
# 2021-07-06 22:41:26,411  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000000)
# 2021-07-06 22:41:26,429  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.000000)
# 2021-07-06 22:41:26,447  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000000)
# 2021-07-06 22:41:26,465  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000000)
# 2021-07-06 22:41:26,482  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000000)
# 2021-07-06 22:41:26,500  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000000)
# 2021-07-06 22:41:26,518  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000000)
# 2021-07-06 22:41:26,536  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.000000)
# 2021-07-06 22:41:26,554  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000000)
# 2021-07-06 22:41:26,570  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000000)
# 2021-07-06 22:41:26,583  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.000000)
# 2021-07-06 22:41:26,595  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000000)
# 2021-07-06 22:41:26,607  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000000)
# 2021-07-06 22:41:26,619  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000000)
# 2021-07-06 22:41:26,632  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000000)

# %% [markdown]
# The result is...

# %%
print("Center R.A.   : {:f} deg.".format(result[0]))
print("Center Dec.   : {:f} deg.".format(result[1]))
print("Position angle: {:f} deg.".format(result[2]))
print("Plate scale   : {:e} deg/um".format(result[3]))
# Out:
# Center R.A.   : -0.000574 deg.
# Center Dec.   : 0.000281 deg.
# Position angle: 220.264943 deg.
# Plate scale   : 8.076071e-06 deg/um

# %%
print(result[4:7])
print(result[7:10])
# Out:
# [6.13999146e-07 2.96063568e-06 1.45072145e-06]
# [4.44535971e-06 1.14745761e-06 1.59699910e-06]

# %% [markdown]
# According to the meta part of the input file, the poiunting RA and Dec are 0.0 deg. The position angle is 220.2670421000566 deg. The calculation seems to correctly estimate these parameters.

# %% [markdown]
# Let's compare the ra/dec values calculated from the derived parameters with the true values.

# %%
positions = model(result, pixcrd)
positions = positions.reshape((2,int(positions.size/2))).T

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot(111)
ax.scatter(data['ra'], data['dec'], marker='+', label='Truth')
ax.scatter(data['ra']-360., data['dec'], marker='+', label='')
ax.scatter(positions[:,0], positions[:,1], marker='x', label='Reproduced')
ax.set_xlabel('R.A. (deg)')
ax.set_ylabel('Dec. (deg)')
ax.set_xlim([-0.3,0.3])
#ax.set_aspect('equal', adjustable='box')
ax.legend()

# %% [markdown]
# This plot shows that the reproduced ra/dec values match the true values. (But we still confirm small differences between them.)

# %%
from astropy.coordinates import SkyCoord

c_calc = SkyCoord(positions[:,0]*u.deg, positions[:,1]*u.deg, frame='icrs')
c_true = SkyCoord(data['ra'], data['dec'], frame='icrs')
sep = c_calc.separation(c_true)

# %%
plt.plot(sep.arcsec, '.')
plt.xlabel('Index')
plt.ylabel('Position estimation error (arcsec)')
# Out:
# Text(0, 0.5, 'Position estimation error (arcsec)')

# %% [markdown]
# The above plot shows that the typical positional differences between the reproduced positions and the true positions are around 5arcsec. It seems to be too large. Higher-order polynomial functions might be needed to represent the distortion in this problem.

# %% [markdown]
# If the distortion is not considered, the position matching becomes worse as shown below.

# %%
positions = model([result[0], result[1], result[2], result[3], 0, 0, 0, 0, 0, 0], pixcrd)
positions = positions.reshape((2,int(positions.size/2))).T

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot(111)
ax.scatter(data['ra'], data['dec'], marker='+', label='Truth')
ax.scatter(data['ra']-360., data['dec'], marker='+', label='')
ax.scatter(positions[:,0], positions[:,1], marker='x', label='Reproduced')
ax.set_xlabel('R.A. (deg)')
ax.set_ylabel('Dec. (deg)')
ax.set_xlim([-0.3,0.3])
#ax.set_aspect('equal', adjustable='box')
ax.legend()
