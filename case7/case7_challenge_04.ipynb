# %% [markdown]
# # Case7-challenge04

# %% [markdown]
# In this note, we estimate the field parameters and sky coordinates of objects from the observed positions on the focal plane and pointing information. The data is the updated version of case7. The pointing positions are fixed as constants in this note. The SIP-convention distortion is considered in this note.

# %% [markdown]
# ## Preparation

# %% [markdown]
# At first, we add the analysis directry to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# Next, we load the data.

# %%
import astropy.io.ascii as asc
import astropy.units as u

objects = asc.read('case7_challenge_04.txt') #consists of x (um), y (um), catalog_id, ra (deg), dec (deg), and field.
pointings = asc.read('case7_challenge_04_pointing.txt') # consists of field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# We convert the units of x and y from um to pix with assuming the pixel size to be 15 um.

# %%
pix_size = 15.*u.um
objects['x'] = (objects['x']/pix_size).si
objects['y'] = (objects['y']/pix_size).si
# objects: x (px), y (px), catalog_id, ra (deg), dec (deg), and field.
# pointings: field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# Then, we change the ids for easy handling.

# %%
from astropy.table import unique
import numpy as np

ids = unique(objects, keys='catalog_id')['catalog_id']
objects.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(objects['catalog_id']==ids[i])
    objects['id'][pos] = i

objects.remove_column('catalog_id')
objects.rename_column('id', 'catalog_id')

# %% [markdown]
# Here, we make some arrays for further analysis. One new array is true_radec which stores true ra/dec values. Duplicated information (rows for the same object) is removed, and the rows are sorted with object ids. Another new array is observed_xy. It contains field ids, observed x/y positions on the focal plane, catalog ids, and estimated ra/dec values instead of true ra/dec values. The estimated ra/dec values are initialized to be zero at this moment.

# %%
true_radec = objects['catalog_id', 'ra', 'dec'].copy()
true_radec.sort('catalog_id')
true_radec = unique(true_radec, keys='catalog_id') # consists of catalog_id, ra (deg), and dec (deg).

observed_xy = objects['field', 'x', 'y', 'catalog_id', 'ra', 'dec'].copy()
observed_xy.rename_column('ra', 'ra_est')
observed_xy.rename_column('dec', 'dec_est')
# observed_xy will have field, x (px), y (px), catalog_id, and estimated ra/dec (deg).

# initializing ra_est and dec_est
observed_xy['ra_est']  = 0.0
observed_xy['dec_est'] = 0.0

# %% [markdown]
# In addition, we make another array which stores field parameters. The plate scale is assumed to be the same value for all plates. At this time, an approximated value is stored in a variable (plate_scale).

# %%
field_params = pointings.copy() # field, ra (deg), dec (deg), and pa (deg).
plate_scale = 8.e-6*u.deg*(pix_size/u.um).si # in deg/pix

# %% [markdown]
# Let's check the object distribution on sky.

# %%
import matplotlib.pylab as plt
import numpy as np

color = ['red', 'blue', 'green', 'orange']

for i in range(0, np.max(field_params['field'])+1):
    pos = np.where(objects['field']==i)
    plt.scatter(objects['ra'][pos], objects['dec'][pos], marker='o', facecolor='None', edgecolor=color[i], s=10*i+10)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# We can see that the data consists of four regions and that the overlapped region has a size of about a 1/4 FoV.

# %% [markdown]
# We select the objects in the overlapped region for further analysis.

# %%
true_radec_overlap = true_radec.copy()
observed_xy_overlap = observed_xy.copy()
for cid in true_radec['catalog_id']:
    if np.count_nonzero(observed_xy['catalog_id']==cid)!=4:
        pos = np.where(true_radec_overlap['catalog_id']==cid)[0]
        true_radec_overlap.remove_rows(pos)
        pos = np.where(observed_xy_overlap['catalog_id']==cid)[0]
        observed_xy_overlap.remove_rows(pos)

# %% [markdown]
# Let's check the distribution of the selected objects.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='o', facecolor='None', edgecolor='orange')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# These objects will be used for the following analysis.

# %% [markdown]
# We again modify the catalog id for easy handling.

# %%
ids = unique(true_radec_overlap, keys='catalog_id')['catalog_id']
true_radec_overlap.add_column(-1, name='id')
observed_xy_overlap.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(true_radec_overlap['catalog_id']==ids[i])
    true_radec_overlap['id'][pos] = i
    pos = np.where(observed_xy_overlap['catalog_id']==ids[i])
    observed_xy_overlap['id'][pos] = i

true_radec_overlap.remove_column('catalog_id')
true_radec_overlap.rename_column('id', 'catalog_id')
observed_xy_overlap.remove_column('catalog_id')
observed_xy_overlap.rename_column('id', 'catalog_id')

# %% [markdown]
# ## First guess of the positions

# %% [markdown]
# At first, we define a wcs constructor.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip
import astropy.units as u

def wcs(ra_ptg, dec_ptg, pa_ptg, scale, a=None, b=None, ap=None, bp=None):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale, scale])
    w.wcs.crval=[ra_ptg, dec_ptg]
    w.wcs.ctype=["RA---TAN-SIP", "DEC--TAN-SIP"]
    w.wcs.pc=[[np.cos(pa_ptg*u.deg), -np.sin(pa_ptg*u.deg)],
              [np.sin(pa_ptg*u.deg), np.cos(pa_ptg*u.deg)]]
#    if a is not None and b is not None:
    w.sip = Sip(a, b, ap, bp, [0, 0])
    
    return w

# %% [markdown]
# Then, we estimate the sky coordinates from the observed focal-plane positions and (approximated) field parameters.

# %%
for i in range(0, np.size(field_params)):
    fp = field_params[i]
    w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale.value)
    pos = np.where(observed_xy_overlap['field']==fp['field'])
    ret = w.all_pix2world(np.concatenate(([observed_xy_overlap[pos]['x']], [observed_xy_overlap[pos]['y']])).T, 0)
    observed_xy_overlap['ra_est'][pos]  = ret[:, 0]
    observed_xy_overlap['dec_est'][pos] = ret[:, 1]

# %% [markdown]
# Let's check the true positions and estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(observed_xy_overlap['ra_est'], observed_xy_overlap['dec_est'], marker='+', label='Estimated')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# Here, there are four estimated positions for each object. We take their mean values as the first-guess positions and store them in radec_est array.

# %%
from astropy.table import Table

radec_est = Table(names=['catalog_id', 'ra_est', 'dec_est'],\
           units=[None, u.deg, u.deg],\
           dtype=['int64', 'float64', 'float64'])

cat_ids = unique(observed_xy_overlap, 'catalog_id')['catalog_id']

for i in cat_ids:
    pos = np.where(observed_xy_overlap['catalog_id'] == i)
    ra = np.mean(observed_xy_overlap[pos]['ra_est'])*u.deg
    dec = np.mean(observed_xy_overlap[pos]['dec_est'])*u.deg
    radec_est.add_row([i, ra, dec])

# %% [markdown]
# Let's check the estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='First guess')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# ## Parameter adjustment

# %% [markdown]
# At first, we define a function which calculates x/y positions from the ra/dec values estimated above and the field/catalog ids.

# %%
def xy_calculator(observed_xy, field_params, plate_scale, ap, bp, radec_info):
    # observed_xy:  consists of field, x (px), y (px), catalog_id, ra_est (deg), and dec_est(deg).
    # field_params: consists of field, ra (deg), dec (deg), and pa (deg).
    # radec_info:   consists of catalog_id, ra_est (deg), and dec_est (deg).

    observed_xy_cp = observed_xy.copy()
    observed_xy_cp.rename_column('x', 'x_est')
    observed_xy_cp.rename_column('y', 'y_est')
    observed_xy_cp['x_est']   = None
    observed_xy_cp['y_est']   = None
    observed_xy_cp['ra_est']  = None
    observed_xy_cp['dec_est'] = None

    for i in range(0, np.size(radec_info)):
        pos = np.where(observed_xy_cp['catalog_id']==radec_info[i]['catalog_id'])
        observed_xy_cp['ra_est'][pos]  = radec_info[i]['ra_est']
        observed_xy_cp['dec_est'][pos] = radec_info[i]['dec_est']
    
    for i in range(0, np.size(field_params)):
        fp = field_params[i]
        w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale, ap=ap, bp=bp)
        pos = np.where(observed_xy_cp['field']==fp['field'])
        radec0 = np.concatenate(([observed_xy_cp[pos]['ra_est']], [observed_xy_cp[pos]['dec_est']])).T
        ret = w.sip_foc2pix(w.wcs_world2pix(radec0, 0)-w.wcs.crpix, 0)
        observed_xy_cp['x_est'][pos] = ret[:, 0]
        observed_xy_cp['y_est'][pos] = ret[:, 1]

    return observed_xy_cp['x_est', 'y_est']

# %% [markdown]
# Then, we define a model function to be used in the least-square calculation.

# %%
def model(params, ra_ptgs, dec_ptgs, n_fields, n_objects, dim_sip, observed_xy):
    # params = (pa_ptg..., scale, a..., b..., ra_obj..., dec_obj)
    pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
        np.split(params, [n_fields, n_fields+1,\
                          n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                          n_fields+1+2*(dim_sip+1)**2+n_objects])
    
    field_params = Table(data=[ra_ptgs, dec_ptgs, pa_ptgs, -np.ones(shape=(np.size(ra_ptgs)))],\
                         names=['ra', 'dec', 'pa', 'field'],\
                         units=[u.deg, u.deg, u.deg, None],\
                         dtype=['float64', 'float64', 'float64', 'int64'])
    
    ap_matrix = np.reshape(ap, (dim_sip+1, dim_sip+1))
    bp_matrix = np.reshape(bp, (dim_sip+1, dim_sip+1))
    
    mns = np.concatenate(((0, 1), np.arange(dim_sip+1, 2*(dim_sip)+1)))    
    for mn in mns:
        for m in range(np.max([0, mn-dim_sip]), np.min([mn+1, dim_sip+1])):
            n = mn - m
            ap_matrix[m, n] = 0
            bp_matrix[m, n] = 0

    m, n = np.indices((dim_sip+1, dim_sip+1))
    mn = m + n
    ap_matrix = ap_matrix * (1.e-3**mn)
    bp_matrix = bp_matrix * (1.e-3**mn)
    
    radec_info = Table(data=[ra_objs, dec_objs, -np.ones(shape=(np.size(ra_objs)))],\
                       names=['ra_est', 'dec_est', 'catalog_id'],\
                       units=[u.deg, u.deg, None],\
                       dtype=['float64', 'float64', 'int64'])
    
    field_params['field'] = np.arange(0, np.size(field_params))
    radec_info['catalog_id'] = np.arange(0, np.size(radec_info))
    
    ret = xy_calculator(observed_xy, field_params, scale[0], ap_matrix, bp_matrix, radec_info)

    return np.concatenate((ret['x_est'], ret['y_est']))

# %% [markdown]
# Next, we execute the least-square calculation to derive the field parameters and sky positions of the objects in the overlapped region.

# %%
from common.leastsquare import LeastSquare

dim_sip = 4
ap = np.zeros(shape=(dim_sip+1, dim_sip+1))
bp = np.zeros(shape=(dim_sip+1, dim_sip+1))

ls = LeastSquare(lambda a: model(a, field_params['ra'], field_params['dec'],\
                                 np.size(field_params), np.size(radec_est), dim_sip, observed_xy_overlap),\
                 np.size(observed_xy_overlap)*2)

# constructing a_init (initial parameter set).
a_init = np.array(np.concatenate((field_params['pa'], [plate_scale.value], ap.flatten(), bp.flatten(),\
                                  radec_est['ra_est'], radec_est['dec_est']))) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
measured = np.concatenate((observed_xy_overlap['x'], observed_xy_overlap['y']))
#pos = np.where(measured>180.)
#measured[pos] -= 360.
#pos = np.where(measured<-180.)
#measured[pos] += 360.

result, _ = ls.solve(measured, a_init, max_iteration=100, epsilon=1.e-8)

## pa should be a positive value between 0 and 360.
#if result[3] < 0:
#    result[3] = -result[3]
#    result[2] = result[2] + 180.0
#
#if result[2] > 360.0 or result[2] < 0.0:
#    result[2] = result[2]%360.0
# Out:
# 2021-07-24 15:12:11,671  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:12:11,843  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 0.181419)
# 2021-07-24 15:12:27,764  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:12:28,057  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 0.057084)
# 2021-07-24 15:12:46,151  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:12:46,577  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 0.001688)
# 2021-07-24 15:13:03,267  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:13:03,417  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 0.000517)
# 2021-07-24 15:13:19,141  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:13:19,292  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 0.000356)
# 2021-07-24 15:13:35,080  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:13:35,407  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 0.000241)
# 2021-07-24 15:13:51,200  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:13:51,379  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 0.000140)
# 2021-07-24 15:14:07,234  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:14:07,381  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 0.000142)
# 2021-07-24 15:14:23,432  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:14:23,601  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.000247)
# 2021-07-24 15:14:39,490  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:14:39,652  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.000211)
# 2021-07-24 15:14:55,733  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:14:55,899  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.000078)
# 2021-07-24 15:15:12,058  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:15:12,216  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.000134)
# 2021-07-24 15:15:28,136  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:15:28,307  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.000018)
# 2021-07-24 15:15:44,290  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:15:44,450  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.000150)
# 2021-07-24 15:16:00,337  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:16:00,503  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.000074)
# 2021-07-24 15:16:16,302  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:16:16,464  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000114)
# 2021-07-24 15:16:32,668  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:16:32,833  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000138)
# 2021-07-24 15:16:48,756  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:16:48,917  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.000121)
# 2021-07-24 15:17:05,076  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:17:05,241  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000025)
# 2021-07-24 15:17:21,310  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:17:21,468  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000062)
# 2021-07-24 15:17:36,919  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:17:37,085  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000162)
# 2021-07-24 15:17:53,052  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:17:53,214  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.000100)
# 2021-07-24 15:18:09,194  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:18:09,355  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000215)
# 2021-07-24 15:18:24,722  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:18:24,880  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000206)
# 2021-07-24 15:18:40,437  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:18:40,597  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000176)
# 2021-07-24 15:18:56,100  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:18:56,276  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.000228)
# 2021-07-24 15:19:11,554  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:19:11,721  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000137)
# 2021-07-24 15:19:27,161  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:19:27,299  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.000153)
# 2021-07-24 15:19:42,715  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:19:42,885  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.000226)
# 2021-07-24 15:19:58,394  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:19:58,556  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.000183)
# 2021-07-24 15:20:14,062  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:20:14,231  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000083)
# 2021-07-24 15:20:29,481  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:20:29,641  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000071)
# 2021-07-24 15:20:45,196  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:20:45,362  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000108)
# 2021-07-24 15:21:00,727  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:21:00,890  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000206)
# 2021-07-24 15:21:16,138  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:21:16,301  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000052)
# 2021-07-24 15:21:31,838  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:21:31,992  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000127)
# 2021-07-24 15:21:47,359  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:21:47,521  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000228)
# 2021-07-24 15:22:02,849  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:22:03,016  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000215)
# 2021-07-24 15:22:18,581  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:22:18,744  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000134)
# 2021-07-24 15:22:34,044  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:22:34,218  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000154)
# 2021-07-24 15:22:49,788  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:22:49,960  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.000125)
# 2021-07-24 15:23:05,506  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:23:05,656  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000123)
# 2021-07-24 15:23:20,927  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:23:21,095  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000101)
# 2021-07-24 15:23:36,700  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:23:36,860  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000146)
# 2021-07-24 15:23:52,347  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:23:52,499  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000090)
# 2021-07-24 15:24:07,747  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:24:07,905  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000204)
# 2021-07-24 15:24:23,282  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:24:23,444  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000173)
# 2021-07-24 15:24:38,945  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:24:39,113  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000154)
# 2021-07-24 15:24:54,371  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:24:54,531  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000129)
# 2021-07-24 15:25:10,085  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:25:10,252  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000191)
# 2021-07-24 15:25:25,508  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:25:25,670  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000125)
# 2021-07-24 15:25:41,088  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:25:41,228  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000110)
# 2021-07-24 15:25:56,460  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:25:56,882  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000145)
# 2021-07-24 15:26:12,384  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:26:12,524  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000072)
# 2021-07-24 15:26:28,029  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:26:28,164  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000173)
# 2021-07-24 15:26:43,424  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:26:43,563  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000040)
# 2021-07-24 15:26:59,073  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:26:59,210  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000230)
# 2021-07-24 15:27:14,586  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:27:14,747  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000132)
# 2021-07-24 15:27:29,970  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:27:30,127  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000153)
# 2021-07-24 15:27:45,629  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:27:45,780  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000245)
# 2021-07-24 15:28:01,313  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:28:01,463  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000239)
# 2021-07-24 15:28:16,783  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:28:16,937  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000119)
# 2021-07-24 15:28:32,508  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:28:32,660  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000123)
# 2021-07-24 15:28:48,011  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:28:48,162  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.000182)
# 2021-07-24 15:29:03,713  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:29:03,865  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.000192)
# 2021-07-24 15:29:19,434  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:29:19,588  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.000121)
# 2021-07-24 15:29:34,826  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:29:34,991  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.000289)
# 2021-07-24 15:29:50,584  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:29:50,734  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000139)
# 2021-07-24 15:30:06,318  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:30:06,467  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000310)
# 2021-07-24 15:30:21,721  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:30:21,865  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000121)
# 2021-07-24 15:30:37,282  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:30:37,430  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000157)
# 2021-07-24 15:30:52,999  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:30:53,149  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000116)
# 2021-07-24 15:31:08,449  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:31:08,597  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.000139)
# 2021-07-24 15:31:24,078  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:31:24,228  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000229)
# 2021-07-24 15:31:39,517  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:31:39,665  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.000193)
# 2021-07-24 15:31:55,017  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:31:55,185  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000166)
# 2021-07-24 15:32:10,698  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:32:10,860  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000063)
# 2021-07-24 15:32:26,122  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:32:26,288  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000097)
# 2021-07-24 15:32:41,773  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:32:41,936  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000061)
# 2021-07-24 15:32:57,472  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:32:57,613  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000063)
# 2021-07-24 15:33:12,832  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:33:12,969  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000199)
# 2021-07-24 15:33:28,349  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:33:28,492  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000094)
# 2021-07-24 15:33:43,953  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:33:44,117  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000124)
# 2021-07-24 15:33:59,418  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:33:59,581  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000170)
# 2021-07-24 15:34:15,016  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:34:15,174  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000117)
# 2021-07-24 15:34:30,434  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:34:30,598  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000051)
# 2021-07-24 15:34:45,931  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:34:46,090  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.000081)
# 2021-07-24 15:35:01,466  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:35:01,630  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000036)
# 2021-07-24 15:35:16,873  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:35:17,035  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000103)
# 2021-07-24 15:35:32,399  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:35:32,559  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000090)
# 2021-07-24 15:35:47,913  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:35:48,072  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000082)
# 2021-07-24 15:36:03,321  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:36:03,482  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000148)
# 2021-07-24 15:36:18,849  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:36:19,008  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.000046)
# 2021-07-24 15:36:34,229  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:36:34,389  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000153)
# 2021-07-24 15:36:49,785  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:36:49,944  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000102)
# 2021-07-24 15:37:05,309  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:37:05,471  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.000218)
# 2021-07-24 15:37:20,713  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:37:20,872  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000232)
# 2021-07-24 15:37:36,258  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:37:36,418  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000148)
# 2021-07-24 15:37:51,777  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:37:51,936  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000038)
# 2021-07-24 15:38:07,204  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:38:07,365  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000028)

# %% [markdown]
# ### Checking results

# %% [markdown]
# #### Preparation

# %%
n_fields = np.size(field_params)
n_objects = np.size(radec_est)
ra_ptgs = field_params['ra']
dec_ptgs= field_params['dec']
pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
    np.split(result, [n_fields, n_fields+1,\
                      n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                      n_fields+1+2*(dim_sip+1)**2+n_objects])

# %% [markdown]
# #### Scale (deg/pix)

# %%
scale
# Out:
# array([0.00011773])

# %% [markdown]
# #### Object positions

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='Initial guess')
plt.scatter(ra_objs, dec_objs, marker='.', label='Final estimation')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Object positions')
plt.legend()

# %% [markdown]
# #### AP/BP matrices (must be scaled as described in the model function)

# %%
np.reshape(ap, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 1.76733212e-12,  1.72537394e-13, -3.81954693e-02,
#          5.56909238e-03, -6.49803870e-02],
#        [-4.48862540e-13, -1.79964611e-02,  2.84813181e-03,
#         -1.61409661e-02,  4.96826655e-13],
#        [-3.60336274e-02,  1.00984585e-03, -1.71784748e-02,
#          1.05441575e-13,  1.67866465e-12],
#        [ 8.30898675e-03, -5.36145739e-02,  4.70565762e-14,
#         -8.60036494e-14, -3.52586601e-13],
#        [-4.92917813e-02,  2.06080643e-12, -3.08647108e-12,
#          9.82888863e-14, -2.12661091e-13]])

# %%
np.reshape(bp, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 1.91366505e-13,  7.06070333e-13,  6.21382357e-02,
#         -1.11639921e-02,  8.73720240e-02],
#        [-1.53290866e-15, -2.08939092e-02, -2.51903922e-03,
#          1.87150844e-02,  5.30770002e-15],
#        [ 3.22557758e-02, -2.27944588e-03,  1.20805610e-02,
#          3.83849310e-15,  3.35985360e-15],
#        [ 1.69184737e-03,  9.54581063e-03, -1.98469716e-16,
#          2.36909926e-16, -1.06817135e-14],
#        [ 3.22635424e-02,  5.13193909e-15,  4.32825116e-15,
#         -7.43337906e-15,  7.31313185e-15]])

# %% [markdown]
# #### Position difference

# %%
from astropy.coordinates import SkyCoord

distlist = []
for i in range(0, np.size(ra_objs)):
    c1 = SkyCoord(ra_objs[i]*u.deg, dec_objs[i]*u.deg)
    c2 = SkyCoord(true_radec_overlap['ra'][i]*u.deg, true_radec_overlap['dec'][i]*u.deg)
    distlist.append(c1.separation(c2).arcsec)
distlist = np.array(distlist)

# %%
#plt.hist(np.log10(distlist))
plt.hist(distlist)
plt.xlabel("Residual (arcsec)")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %% [markdown]
# #### Residual in focal-plane positions

# %%
ret = model(result, field_params['ra'], field_params['dec'], n_fields, n_objects, dim_sip, observed_xy_overlap)
dx = ret[0:int(ret.size*0.5)] - observed_xy_overlap['x']
dy = ret[int(ret.size*0.5):int(ret.size)] - observed_xy_overlap['y']
#plt.scatter(observed_xy_overlap['x'], observed_xy_overlap['y'], marker='+')
#plt.scatter(ret[0:900], ret[900:1800], marker='x')
plt.scatter(dx, dy, marker='x')
plt.xlabel('dx (pix)')
plt.ylabel('dy (pix)')
plt.xlim([-0.2, 0.2])
plt.ylim([-0.2, 0.2])
# Out:
# (-0.2, 0.2)

# %%
ret.size
# Out:
# 2352
