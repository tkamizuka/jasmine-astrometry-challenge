# %% [markdown]
# # Case7-challenge02

# %% [markdown]
# In this note, we estimate the field parameters and sky coordinates of objects from the observed positions on the focal plane and pointing information. The data is the updated version of case7. The pointing positions are fixed as constants in this note. The SIP-convention distortion is considered in this note.

# %% [markdown]
# ## Preparation

# %% [markdown]
# At first, we add the analysis directry to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# Next, we load the data.

# %%
import astropy.io.ascii as asc
import astropy.units as u

objects = asc.read('case7_challenge_02.txt') #consists of x (um), y (um), catalog_id, ra (deg), dec (deg), and field.
pointings = asc.read('case7_challenge_02_pointing.txt') # consists of field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# We convert the units of x and y from um to pix with assuming the pixel size to be 15 um.

# %%
pix_size = 15.*u.um
objects['x'] = (objects['x']/pix_size).si
objects['y'] = (objects['y']/pix_size).si
# objects: x (px), y (px), catalog_id, ra (deg), dec (deg), and field.
# pointings: field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# Then, we change the ids for easy handling.

# %%
from astropy.table import unique
import numpy as np

ids = unique(objects, keys='catalog_id')['catalog_id']
objects.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(objects['catalog_id']==ids[i])
    objects['id'][pos] = i

objects.remove_column('catalog_id')
objects.rename_column('id', 'catalog_id')

# %% [markdown]
# Here, we make some arrays for further analysis. One new array is true_radec which stores true ra/dec values. Duplicated information (rows for the same object) is removed, and the rows are sorted with object ids. Another new array is observed_xy. It contains field ids, observed x/y positions on the focal plane, catalog ids, and estimated ra/dec values instead of true ra/dec values. The estimated ra/dec values are initialized to be zero at this moment.

# %%
true_radec = objects['catalog_id', 'ra', 'dec'].copy()
true_radec.sort('catalog_id')
true_radec = unique(true_radec, keys='catalog_id') # consists of catalog_id, ra (deg), and dec (deg).

observed_xy = objects['field', 'x', 'y', 'catalog_id', 'ra', 'dec'].copy()
observed_xy.rename_column('ra', 'ra_est')
observed_xy.rename_column('dec', 'dec_est')
# observed_xy will have field, x (px), y (px), catalog_id, and estimated ra/dec (deg).

# initializing ra_est and dec_est
observed_xy['ra_est']  = 0.0
observed_xy['dec_est'] = 0.0

# %% [markdown]
# In addition, we make another array which stores field parameters. The plate scale is assumed to be the same value for all plates. At this time, an approximated value is stored in a variable (plate_scale).

# %%
field_params = pointings.copy() # field, ra (deg), dec (deg), and pa (deg).
plate_scale = 8.e-6*u.deg*(pix_size/u.um).si # in deg/pix

# %% [markdown]
# Let's check the object distribution on sky.

# %%
import matplotlib.pylab as plt
import numpy as np

color = ['red', 'blue', 'green', 'orange']

for i in range(0, np.max(field_params['field'])+1):
    pos = np.where(objects['field']==i)
    plt.scatter(objects['ra'][pos], objects['dec'][pos], marker='o', facecolor='None', edgecolor=color[i], s=10*i+10)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# We can see that the data consists of four regions and that the overlapped region has a size of about a 1/4 FoV.

# %% [markdown]
# We select the objects in the overlapped region for further analysis.

# %%
true_radec_overlap = true_radec.copy()
observed_xy_overlap = observed_xy.copy()
for cid in true_radec['catalog_id']:
    if np.count_nonzero(observed_xy['catalog_id']==cid)!=4:
        pos = np.where(true_radec_overlap['catalog_id']==cid)[0]
        true_radec_overlap.remove_rows(pos)
        pos = np.where(observed_xy_overlap['catalog_id']==cid)[0]
        observed_xy_overlap.remove_rows(pos)

# %% [markdown]
# Let's check the distribution of the selected objects.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='o', facecolor='None', edgecolor='orange')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# These objects will be used for the following analysis.

# %% [markdown]
# We again modify the catalog id for easy handling.

# %%
ids = unique(true_radec_overlap, keys='catalog_id')['catalog_id']
true_radec_overlap.add_column(-1, name='id')
observed_xy_overlap.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(true_radec_overlap['catalog_id']==ids[i])
    true_radec_overlap['id'][pos] = i
    pos = np.where(observed_xy_overlap['catalog_id']==ids[i])
    observed_xy_overlap['id'][pos] = i

true_radec_overlap.remove_column('catalog_id')
true_radec_overlap.rename_column('id', 'catalog_id')
observed_xy_overlap.remove_column('catalog_id')
observed_xy_overlap.rename_column('id', 'catalog_id')

# %% [markdown]
# ## First guess of the positions

# %% [markdown]
# At first, we define a wcs constructor.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip
import astropy.units as u

def wcs(ra_ptg, dec_ptg, pa_ptg, scale, a=None, b=None, ap=None, bp=None):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale, scale])
    w.wcs.crval=[ra_ptg, dec_ptg]
    w.wcs.ctype=["RA---TAN-SIP", "DEC--TAN-SIP"]
    w.wcs.pc=[[np.cos(pa_ptg*u.deg), -np.sin(pa_ptg*u.deg)],
              [np.sin(pa_ptg*u.deg), np.cos(pa_ptg*u.deg)]]
#    if a is not None and b is not None:
    w.sip = Sip(a, b, ap, bp, [0, 0])
    
    return w

# %% [markdown]
# Then, we estimate the sky coordinates from the observed focal-plane positions and (approximated) field parameters.

# %%
for i in range(0, np.size(field_params)):
    fp = field_params[i]
    w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale.value)
    pos = np.where(observed_xy_overlap['field']==fp['field'])
    ret = w.all_pix2world(np.concatenate(([observed_xy_overlap[pos]['x']], [observed_xy_overlap[pos]['y']])).T, 0)
    observed_xy_overlap['ra_est'][pos]  = ret[:, 0]
    observed_xy_overlap['dec_est'][pos] = ret[:, 1]

# %% [markdown]
# Let's check the true positions and estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(observed_xy_overlap['ra_est'], observed_xy_overlap['dec_est'], marker='+', label='Estimated')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# Here, there are four estimated positions for each object. We take their mean values as the first-guess positions and store them in radec_est array.

# %%
from astropy.table import Table

radec_est = Table(names=['catalog_id', 'ra_est', 'dec_est'],\
           units=[None, u.deg, u.deg],\
           dtype=['int64', 'float64', 'float64'])

cat_ids = unique(observed_xy_overlap, 'catalog_id')['catalog_id']

for i in cat_ids:
    pos = np.where(observed_xy_overlap['catalog_id'] == i)
    ra = np.mean(observed_xy_overlap[pos]['ra_est'])*u.deg
    dec = np.mean(observed_xy_overlap[pos]['dec_est'])*u.deg
    radec_est.add_row([i, ra, dec])

# %% [markdown]
# Let's check the estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='First guess')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# ## Parameter adjustment

# %% [markdown]
# At first, we define a function which calculates x/y positions from the ra/dec values estimated above and the field/catalog ids.

# %%
def xy_calculator(observed_xy, field_params, plate_scale, ap, bp, radec_info):
    # observed_xy:  consists of field, x (px), y (px), catalog_id, ra_est (deg), and dec_est(deg).
    # field_params: consists of field, ra (deg), dec (deg), and pa (deg).
    # radec_info:   consists of catalog_id, ra_est (deg), and dec_est (deg).

    observed_xy_cp = observed_xy.copy()
    observed_xy_cp.rename_column('x', 'x_est')
    observed_xy_cp.rename_column('y', 'y_est')
    observed_xy_cp['x_est']   = None
    observed_xy_cp['y_est']   = None
    observed_xy_cp['ra_est']  = None
    observed_xy_cp['dec_est'] = None

    for i in range(0, np.size(radec_info)):
        pos = np.where(observed_xy_cp['catalog_id']==radec_info[i]['catalog_id'])
        observed_xy_cp['ra_est'][pos]  = radec_info[i]['ra_est']
        observed_xy_cp['dec_est'][pos] = radec_info[i]['dec_est']
    
    for i in range(0, np.size(field_params)):
        fp = field_params[i]
        w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale, ap=ap, bp=bp)
        pos = np.where(observed_xy_cp['field']==fp['field'])
        radec0 = np.concatenate(([observed_xy_cp[pos]['ra_est']], [observed_xy_cp[pos]['dec_est']])).T
        ret = w.sip_foc2pix(w.wcs_world2pix(radec0, 0)-w.wcs.crpix, 0)
        observed_xy_cp['x_est'][pos] = ret[:, 0]
        observed_xy_cp['y_est'][pos] = ret[:, 1]

    return observed_xy_cp['x_est', 'y_est']

# %% [markdown]
# Then, we define a model function to be used in the least-square calculation.

# %%
def model(params, ra_ptgs, dec_ptgs, n_fields, n_objects, dim_sip, observed_xy):
    # params = (pa_ptg..., scale, a..., b..., ra_obj..., dec_obj)
    pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
        np.split(params, [n_fields, n_fields+1,\
                          n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                          n_fields+1+2*(dim_sip+1)**2+n_objects])
    
    field_params = Table(data=[ra_ptgs, dec_ptgs, pa_ptgs, -np.ones(shape=(np.size(ra_ptgs)))],\
                         names=['ra', 'dec', 'pa', 'field'],\
                         units=[u.deg, u.deg, u.deg, None],\
                         dtype=['float64', 'float64', 'float64', 'int64'])
    
    ap_matrix = np.reshape(ap, (dim_sip+1, dim_sip+1))
    bp_matrix = np.reshape(bp, (dim_sip+1, dim_sip+1))
    
    mns = np.concatenate(((0, 1), np.arange(dim_sip+1, 2*(dim_sip)+1)))    
    for mn in mns:
        for m in range(np.max([0, mn-dim_sip]), np.min([mn+1, dim_sip+1])):
            n = mn - m
            ap_matrix[m, n] = 0
            bp_matrix[m, n] = 0

    m, n = np.indices((dim_sip+1, dim_sip+1))
    mn = m + n
    ap_matrix = ap_matrix * (1.e-3**mn)
    bp_matrix = bp_matrix * (1.e-3**mn)
    
    radec_info = Table(data=[ra_objs, dec_objs, -np.ones(shape=(np.size(ra_objs)))],\
                       names=['ra_est', 'dec_est', 'catalog_id'],\
                       units=[u.deg, u.deg, None],\
                       dtype=['float64', 'float64', 'int64'])
    
    field_params['field'] = np.arange(0, np.size(field_params))
    radec_info['catalog_id'] = np.arange(0, np.size(radec_info))
    
    ret = xy_calculator(observed_xy, field_params, scale[0], ap_matrix, bp_matrix, radec_info)

    return np.concatenate((ret['x_est'], ret['y_est']))

# %% [markdown]
# Next, we execute the least-square calculation to derive the field parameters and sky positions of the objects in the overlapped region.

# %%
from common.leastsquare import LeastSquare

dim_sip = 4
ap = np.zeros(shape=(dim_sip+1, dim_sip+1))
bp = np.zeros(shape=(dim_sip+1, dim_sip+1))

ls = LeastSquare(lambda a: model(a, field_params['ra'], field_params['dec'],\
                                 np.size(field_params), np.size(radec_est), dim_sip, observed_xy_overlap),\
                 np.size(observed_xy_overlap)*2)

# constructing a_init (initial parameter set).
a_init = np.array(np.concatenate((field_params['pa'], [plate_scale.value], ap.flatten(), bp.flatten(),\
                                  radec_est['ra_est'], radec_est['dec_est']))) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
measured = np.concatenate((observed_xy_overlap['x'], observed_xy_overlap['y']))
#pos = np.where(measured>180.)
#measured[pos] -= 360.
#pos = np.where(measured<-180.)
#measured[pos] += 360.

result, _ = ls.solve(measured, a_init, max_iteration=100, epsilon=1.e-8)

## pa should be a positive value between 0 and 360.
#if result[3] < 0:
#    result[3] = -result[3]
#    result[2] = result[2] + 180.0
#
#if result[2] > 360.0 or result[2] < 0.0:
#    result[2] = result[2]%360.0
# Out:
# 2021-07-24 15:04:45,547  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:04:45,822  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 0.196602)
# 2021-07-24 15:05:09,965  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:05:10,261  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 0.068941)
# 2021-07-24 15:05:34,373  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:05:34,652  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 0.014531)
# 2021-07-24 15:05:58,853  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:05:59,121  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 0.003715)
# 2021-07-24 15:06:23,266  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:06:23,551  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 0.000658)
# 2021-07-24 15:06:47,656  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:06:47,925  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 0.000347)
# 2021-07-24 15:07:11,999  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:07:12,281  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 0.000062)
# 2021-07-24 15:07:36,325  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:07:36,590  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 0.000145)
# 2021-07-24 15:08:00,689  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:08:00,976  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.000257)
# 2021-07-24 15:08:25,265  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:08:25,542  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.000159)
# 2021-07-24 15:08:49,540  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:08:49,832  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.000160)
# 2021-07-24 15:09:13,877  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:09:14,145  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.000310)
# 2021-07-24 15:09:38,177  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:09:38,463  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.000102)
# 2021-07-24 15:10:02,530  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:10:02,812  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.000140)
# 2021-07-24 15:10:26,810  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:10:27,088  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.000116)
# 2021-07-24 15:10:52,774  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:10:53,041  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000224)
# 2021-07-24 15:11:17,409  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:11:17,688  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000183)
# 2021-07-24 15:11:42,483  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:11:42,765  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.000076)
# 2021-07-24 15:12:07,965  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:12:08,246  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000096)
# 2021-07-24 15:12:33,888  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:12:34,173  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000283)
# 2021-07-24 15:13:00,377  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:13:00,658  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000365)
# 2021-07-24 15:13:25,745  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:13:26,015  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.000185)
# 2021-07-24 15:13:50,689  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:13:50,967  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000117)
# 2021-07-24 15:14:15,785  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:14:16,058  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000104)
# 2021-07-24 15:14:41,276  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:14:41,551  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000206)
# 2021-07-24 15:15:06,597  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:15:06,869  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.000131)
# 2021-07-24 15:15:32,259  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:15:32,497  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000080)
# 2021-07-24 15:15:57,502  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:15:57,774  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.010291)
# 2021-07-24 15:16:23,080  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:16:23,350  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.001994)
# 2021-07-24 15:16:48,157  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:16:48,440  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.000512)
# 2021-07-24 15:17:13,857  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:17:14,132  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000161)
# 2021-07-24 15:17:39,193  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:17:39,489  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000221)
# 2021-07-24 15:18:04,848  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:18:05,121  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000351)
# 2021-07-24 15:18:29,743  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:18:30,012  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000076)
# 2021-07-24 15:18:54,167  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:18:54,433  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000333)
# 2021-07-24 15:19:18,653  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:19:18,915  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000069)
# 2021-07-24 15:19:43,139  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:19:43,396  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000095)
# 2021-07-24 15:20:07,541  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:20:07,802  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000051)
# 2021-07-24 15:20:32,083  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:20:32,424  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000211)
# 2021-07-24 15:20:56,705  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:20:56,964  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000402)
# 2021-07-24 15:21:21,227  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:21:21,477  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.000430)
# 2021-07-24 15:21:45,635  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:21:45,893  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000078)
# 2021-07-24 15:22:10,214  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:22:10,480  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000267)
# 2021-07-24 15:22:34,759  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:22:35,023  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000400)
# 2021-07-24 15:22:59,238  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:22:59,488  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000527)
# 2021-07-24 15:23:23,817  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:23:24,073  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000096)
# 2021-07-24 15:23:48,276  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:23:48,531  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000210)
# 2021-07-24 15:24:12,998  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:24:13,270  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000194)
# 2021-07-24 15:24:37,486  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:24:37,744  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000207)
# 2021-07-24 15:25:02,106  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:25:02,370  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000112)
# 2021-07-24 15:25:29,378  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:25:29,673  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000095)
# 2021-07-24 15:25:57,028  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:25:57,302  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000025)
# 2021-07-24 15:26:21,533  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:26:21,784  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000178)
# 2021-07-24 15:26:46,081  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:26:46,376  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000268)
# 2021-07-24 15:27:10,564  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:27:10,853  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000249)
# 2021-07-24 15:27:35,131  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:27:35,427  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000064)
# 2021-07-24 15:27:59,687  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:27:59,993  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000042)
# 2021-07-24 15:28:24,356  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:28:24,653  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000174)
# 2021-07-24 15:28:49,010  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:28:49,318  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000088)
# 2021-07-24 15:29:13,584  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:29:13,874  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000031)
# 2021-07-24 15:29:38,178  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:29:38,489  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000124)
# 2021-07-24 15:30:02,767  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:30:03,064  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000185)
# 2021-07-24 15:30:27,345  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:30:27,652  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000099)
# 2021-07-24 15:30:51,896  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:30:52,190  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.000087)
# 2021-07-24 15:31:16,695  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:31:16,962  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.009715)
# 2021-07-24 15:31:41,262  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:31:41,522  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.001974)
# 2021-07-24 15:32:05,684  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:32:05,959  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.001118)
# 2021-07-24 15:32:30,223  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:32:30,468  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000287)
# 2021-07-24 15:32:54,637  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:32:54,894  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000028)
# 2021-07-24 15:33:19,118  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:33:19,355  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000093)
# 2021-07-24 15:33:43,527  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:33:43,812  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000122)
# 2021-07-24 15:34:08,202  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:34:08,437  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000094)
# 2021-07-24 15:34:32,721  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:34:32,963  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.000059)
# 2021-07-24 15:34:57,145  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:34:57,411  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000054)
# 2021-07-24 15:35:21,718  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:35:21,984  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.000153)
# 2021-07-24 15:35:46,159  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:35:46,425  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000242)
# 2021-07-24 15:36:10,763  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:36:11,042  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000075)
# 2021-07-24 15:36:35,272  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:36:35,536  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000230)
# 2021-07-24 15:36:59,652  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:36:59,922  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000079)
# 2021-07-24 15:37:24,169  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:37:24,441  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000074)
# 2021-07-24 15:37:48,540  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:37:48,826  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000122)
# 2021-07-24 15:38:13,041  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:38:13,309  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000133)
# 2021-07-24 15:38:37,352  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:38:37,637  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000259)
# 2021-07-24 15:39:01,670  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:39:01,939  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000083)
# 2021-07-24 15:39:25,977  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:39:26,265  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000096)
# 2021-07-24 15:39:50,337  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:39:50,610  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000092)
# 2021-07-24 15:40:14,678  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:40:14,967  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.000087)
# 2021-07-24 15:40:39,031  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:40:39,305  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000469)
# 2021-07-24 15:41:03,381  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:41:03,675  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000255)
# 2021-07-24 15:41:27,706  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:41:27,982  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000214)
# 2021-07-24 15:41:52,042  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:41:52,323  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000093)
# 2021-07-24 15:42:16,395  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:42:16,676  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000073)
# 2021-07-24 15:42:40,724  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:42:41,021  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.000147)
# 2021-07-24 15:43:05,091  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:43:05,375  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000034)
# 2021-07-24 15:43:29,456  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:43:29,744  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000108)
# 2021-07-24 15:43:53,771  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:43:54,053  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.000055)
# 2021-07-24 15:44:18,103  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:44:18,390  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000098)
# 2021-07-24 15:44:42,435  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:44:42,722  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000140)
# 2021-07-24 15:45:06,743  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:45:07,043  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000254)
# 2021-07-24 15:45:31,025  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 15:45:31,307  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000175)

# %% [markdown]
# ### Checking results

# %% [markdown]
# #### Preparation

# %%
n_fields = np.size(field_params)
n_objects = np.size(radec_est)
ra_ptgs = field_params['ra']
dec_ptgs= field_params['dec']
pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
    np.split(result, [n_fields, n_fields+1,\
                      n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                      n_fields+1+2*(dim_sip+1)**2+n_objects])

# %% [markdown]
# #### Scale (deg/pix)

# %%
scale
# Out:
# array([0.00011773])

# %% [markdown]
# #### Object positions

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='Initial guess')
plt.scatter(ra_objs, dec_objs, marker='.', label='Final estimation')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Object positions')
plt.legend()

# %% [markdown]
# #### AP/BP matrices (must be scaled as described in the model function)

# %%
np.reshape(ap, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 5.60508371e-11,  2.54234203e-11, -6.29397271e-03,
#         -2.88440131e-03,  1.34866899e-02],
#        [-8.28930795e-12,  3.07618763e-02,  5.07292414e-03,
#          5.18589169e-03,  5.71229088e-12],
#        [ 9.83487162e-04, -2.67198058e-03,  8.69645124e-03,
#          8.17516965e-11,  5.65803960e-10],
#        [-4.27596576e-03,  1.05993869e-02,  3.89481101e-11,
#         -6.55199850e-12,  2.96698848e-11],
#        [-7.88213735e-03, -2.76024943e-10,  1.42242883e-11,
#          1.16829240e-11, -9.72347497e-12]])

# %%
np.reshape(bp, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 4.73053288e-12,  1.64552893e-12, -1.80729788e-02,
#          6.46448681e-03, -1.70929672e-02],
#        [ 1.21290564e-15, -7.75580055e-02, -1.85908896e-03,
#         -8.74318867e-02,  7.33315079e-14],
#        [ 2.32956570e-02,  2.91757069e-05,  4.63126465e-03,
#         -1.41353787e-13, -4.90080360e-14],
#        [-1.98628217e-02, -6.06028335e-02,  2.55116112e-14,
#         -5.26274052e-14, -7.08337559e-14],
#        [ 2.06654841e-02,  1.44337549e-13,  4.00207227e-14,
#         -2.66103333e-14, -6.98639950e-15]])

# %% [markdown]
# #### Position difference

# %%
from astropy.coordinates import SkyCoord

distlist = []
for i in range(0, np.size(ra_objs)):
    c1 = SkyCoord(ra_objs[i]*u.deg, dec_objs[i]*u.deg)
    c2 = SkyCoord(true_radec_overlap['ra'][i]*u.deg, true_radec_overlap['dec'][i]*u.deg)
    distlist.append(c1.separation(c2).arcsec)
distlist = np.array(distlist)

# %%
#plt.hist(np.log10(distlist))
plt.hist(distlist)
plt.xlabel("Residual (arcsec)")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %% [markdown]
# #### Residual in focal-plane positions

# %%
ret = model(result, field_params['ra'], field_params['dec'], n_fields, n_objects, dim_sip, observed_xy_overlap)
dx = ret[0:int(ret.size*0.5)] - observed_xy_overlap['x']
dy = ret[int(ret.size*0.5):int(ret.size)] - observed_xy_overlap['y']
#plt.scatter(observed_xy_overlap['x'], observed_xy_overlap['y'], marker='+')
#plt.scatter(ret[0:900], ret[900:1800], marker='x')
plt.scatter(dx, dy, marker='x')
plt.xlabel('dx (pix)')
plt.ylabel('dy (pix)')
plt.xlim([-0.2, 0.2])
plt.ylim([-0.2, 0.2])
# Out:
# (-0.2, 0.2)

# %%
ret.size
# Out:
# 3096
