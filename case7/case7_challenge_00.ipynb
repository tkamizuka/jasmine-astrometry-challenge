# %% [markdown]
# # Case7-challenge00

# %% [markdown]
# In this note, we estimate the field parameters and sky coordinates of objects from the observed positions on the focal plane and pointing information. The data is the updated version of case7. The pointing positions are fixed as constants in this note. The SIP-convention distortion is considered in this note.

# %% [markdown]
# ## Preparation

# %% [markdown]
# At first, we add the analysis directry to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# Next, we load the data.

# %%
import astropy.io.ascii as asc
import astropy.units as u

objects = asc.read('case7_challenge_00.txt') #consists of x (um), y (um), catalog_id, ra (deg), dec (deg), and field.
pointings = asc.read('case7_challenge_00_pointing.txt') # consists of field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# We convert the units of x and y from um to pix with assuming the pixel size to be 15 um.

# %%
pix_size = 15.*u.um
objects['x'] = (objects['x']/pix_size).si
objects['y'] = (objects['y']/pix_size).si
# objects: x (px), y (px), catalog_id, ra (deg), dec (deg), and field.
# pointings: field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# Then, we change the ids for easy handling.

# %%
from astropy.table import unique
import numpy as np

ids = unique(objects, keys='catalog_id')['catalog_id']
objects.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(objects['catalog_id']==ids[i])
    objects['id'][pos] = i

objects.remove_column('catalog_id')
objects.rename_column('id', 'catalog_id')

# %% [markdown]
# Here, we make some arrays for further analysis. One new array is true_radec which stores true ra/dec values. Duplicated information (rows for the same object) is removed, and the rows are sorted with object ids. Another new array is observed_xy. It contains field ids, observed x/y positions on the focal plane, catalog ids, and estimated ra/dec values instead of true ra/dec values. The estimated ra/dec values are initialized to be zero at this moment.

# %%
true_radec = objects['catalog_id', 'ra', 'dec'].copy()
true_radec.sort('catalog_id')
true_radec = unique(true_radec, keys='catalog_id') # consists of catalog_id, ra (deg), and dec (deg).

observed_xy = objects['field', 'x', 'y', 'catalog_id', 'ra', 'dec'].copy()
observed_xy.rename_column('ra', 'ra_est')
observed_xy.rename_column('dec', 'dec_est')
# observed_xy will have field, x (px), y (px), catalog_id, and estimated ra/dec (deg).

# initializing ra_est and dec_est
observed_xy['ra_est']  = 0.0
observed_xy['dec_est'] = 0.0

# %% [markdown]
# In addition, we make another array which stores field parameters. The plate scale is assumed to be the same value for all plates. At this time, an approximated value is stored in a variable (plate_scale).

# %%
field_params = pointings.copy() # field, ra (deg), dec (deg), and pa (deg).
plate_scale = 8.e-6*u.deg*(pix_size/u.um).si # in deg/pix

# %% [markdown]
# Let's check the object distribution on sky.

# %%
import matplotlib.pylab as plt

# %%
import numpy as np

color = ['red', 'blue', 'green', 'orange']

for i in range(0, np.max(field_params['field'])+1):
    pos = np.where(objects['field']==i)
    plt.scatter(objects['ra'][pos], objects['dec'][pos], marker='o', facecolor='None', edgecolor=color[i], s=10*i+10)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# We can see that the data consists of four regions and that the overlapped region has a size of about a 1/4 FoV.

# %% [markdown]
# We select the objects in the overlapped region for further analysis.

# %%
true_radec_overlap = true_radec.copy()
observed_xy_overlap = observed_xy.copy()
for cid in true_radec['catalog_id']:
    if np.count_nonzero(observed_xy['catalog_id']==cid)!=4:
        pos = np.where(true_radec_overlap['catalog_id']==cid)[0]
        true_radec_overlap.remove_rows(pos)
        pos = np.where(observed_xy_overlap['catalog_id']==cid)[0]
        observed_xy_overlap.remove_rows(pos)

# %% [markdown]
# Let's check the distribution of the selected objects.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='o', facecolor='None', edgecolor='orange')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# These objects will be used for the following analysis.

# %% [markdown]
# We again modify the catalog id for easy handling.

# %%
ids = unique(true_radec_overlap, keys='catalog_id')['catalog_id']
true_radec_overlap.add_column(-1, name='id')
observed_xy_overlap.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(true_radec_overlap['catalog_id']==ids[i])
    true_radec_overlap['id'][pos] = i
    pos = np.where(observed_xy_overlap['catalog_id']==ids[i])
    observed_xy_overlap['id'][pos] = i

true_radec_overlap.remove_column('catalog_id')
true_radec_overlap.rename_column('id', 'catalog_id')
observed_xy_overlap.remove_column('catalog_id')
observed_xy_overlap.rename_column('id', 'catalog_id')

# %% [markdown]
# ## First guess of the positions

# %% [markdown]
# At first, we define a wcs constructor.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip
import astropy.units as u

def wcs(ra_ptg, dec_ptg, pa_ptg, scale, a=None, b=None, ap=None, bp=None):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale, scale])
    w.wcs.crval=[ra_ptg, dec_ptg]
    w.wcs.ctype=["RA---TAN-SIP", "DEC--TAN-SIP"]
    w.wcs.pc=[[np.cos(pa_ptg*u.deg), -np.sin(pa_ptg*u.deg)],
              [np.sin(pa_ptg*u.deg), np.cos(pa_ptg*u.deg)]]
#    if a is not None and b is not None:
    w.sip = Sip(a, b, ap, bp, [0, 0])
    
    return w

# %% [markdown]
# Then, we estimate the sky coordinates from the observed focal-plane positions and (approximated) field parameters.

# %%
for i in range(0, np.size(field_params)):
    fp = field_params[i]
    w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale.value)
    pos = np.where(observed_xy_overlap['field']==fp['field'])
    ret = w.all_pix2world(np.concatenate(([observed_xy_overlap[pos]['x']], [observed_xy_overlap[pos]['y']])).T, 0)
    observed_xy_overlap['ra_est'][pos]  = ret[:, 0]
    observed_xy_overlap['dec_est'][pos] = ret[:, 1]

# %% [markdown]
# Let's check the true positions and estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(observed_xy_overlap['ra_est'], observed_xy_overlap['dec_est'], marker='+', label='Estimated')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# Here, there are four estimated positions for each object. We take their mean values as the first-guess positions and store them in radec_est array.

# %%
from astropy.table import Table

radec_est = Table(names=['catalog_id', 'ra_est', 'dec_est'],\
           units=[None, u.deg, u.deg],\
           dtype=['int64', 'float64', 'float64'])

cat_ids = unique(observed_xy_overlap, 'catalog_id')['catalog_id']

for i in cat_ids:
    pos = np.where(observed_xy_overlap['catalog_id'] == i)
    ra = np.mean(observed_xy_overlap[pos]['ra_est'])*u.deg
    dec = np.mean(observed_xy_overlap[pos]['dec_est'])*u.deg
    radec_est.add_row([i, ra, dec])

# %% [markdown]
# Let's check the estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='First guess')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# ## Parameter adjustment

# %% [markdown]
# At first, we define a function which calculates x/y positions from the ra/dec values estimated above and the field/catalog ids.

# %%
def xy_calculator(observed_xy, field_params, plate_scale, ap, bp, radec_info):
    # observed_xy:  consists of field, x (px), y (px), catalog_id, ra_est (deg), and dec_est(deg).
    # field_params: consists of field, ra (deg), dec (deg), and pa (deg).
    # radec_info:   consists of catalog_id, ra_est (deg), and dec_est (deg).

    observed_xy_cp = observed_xy.copy()
    observed_xy_cp.rename_column('x', 'x_est')
    observed_xy_cp.rename_column('y', 'y_est')
    observed_xy_cp['x_est']   = None
    observed_xy_cp['y_est']   = None
    observed_xy_cp['ra_est']  = None
    observed_xy_cp['dec_est'] = None

    for i in range(0, np.size(radec_info)):
        pos = np.where(observed_xy_cp['catalog_id']==radec_info[i]['catalog_id'])
        observed_xy_cp['ra_est'][pos]  = radec_info[i]['ra_est']
        observed_xy_cp['dec_est'][pos] = radec_info[i]['dec_est']
    
    for i in range(0, np.size(field_params)):
        fp = field_params[i]
        w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale, ap=ap, bp=bp)
        pos = np.where(observed_xy_cp['field']==fp['field'])
        radec0 = np.concatenate(([observed_xy_cp[pos]['ra_est']], [observed_xy_cp[pos]['dec_est']])).T
        ret = w.sip_foc2pix(w.wcs_world2pix(radec0, 1)-w.wcs.crpix, 1)
        observed_xy_cp['x_est'][pos] = ret[:, 0]
        observed_xy_cp['y_est'][pos] = ret[:, 1]

    return observed_xy_cp['x_est', 'y_est']

# %% [markdown]
# Then, we define a model function to be used in the least-square calculation.

# %%
def model(params, ra_ptgs, dec_ptgs, n_fields, n_objects, dim_sip, observed_xy):
    # params = (pa_ptg..., scale, a..., b..., ra_obj..., dec_obj)
    pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
        np.split(params, [n_fields, n_fields+1,\
                          n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                          n_fields+1+2*(dim_sip+1)**2+n_objects])
    
    field_params = Table(data=[ra_ptgs, dec_ptgs, pa_ptgs, -np.ones(shape=(np.size(ra_ptgs)))],\
                         names=['ra', 'dec', 'pa', 'field'],\
                         units=[u.deg, u.deg, u.deg, None],\
                         dtype=['float64', 'float64', 'float64', 'int64'])
    
    ap_matrix = np.reshape(ap, (dim_sip+1, dim_sip+1))
    bp_matrix = np.reshape(bp, (dim_sip+1, dim_sip+1))
    
    mns = np.concatenate(((0, 1), np.arange(dim_sip+1, 2*(dim_sip)+1)))    
    for mn in mns:
        for m in range(np.max([0, mn-dim_sip]), np.min([mn+1, dim_sip+1])):
            n = mn - m
            ap_matrix[m, n] = 0
            bp_matrix[m, n] = 0

    m, n = np.indices((dim_sip+1, dim_sip+1))
    mn = m + n
    ap_matrix = ap_matrix * (1.e-3**mn)
    bp_matrix = bp_matrix * (1.e-3**mn)
    
    radec_info = Table(data=[ra_objs, dec_objs, -np.ones(shape=(np.size(ra_objs)))],\
                       names=['ra_est', 'dec_est', 'catalog_id'],\
                       units=[u.deg, u.deg, None],\
                       dtype=['float64', 'float64', 'int64'])
    
    field_params['field'] = np.arange(0, np.size(field_params))
    radec_info['catalog_id'] = np.arange(0, np.size(radec_info))
    
    ret = xy_calculator(observed_xy, field_params, scale[0], ap_matrix, bp_matrix, radec_info)

    return np.concatenate((ret['x_est'], ret['y_est']))

# %% [markdown]
# Next, we execute the least-square calculation to derive the field parameters and sky positions of the objects in the overlapped region.

# %%
from common.leastsquare import LeastSquare

dim_sip = 4
ap = np.zeros(shape=(dim_sip+1, dim_sip+1))
bp = np.zeros(shape=(dim_sip+1, dim_sip+1))

ls = LeastSquare(lambda a: model(a, field_params['ra'], field_params['dec'],\
                                 np.size(field_params), np.size(radec_est), dim_sip, observed_xy_overlap),\
                 np.size(observed_xy_overlap)*2)

# constructing a_init (initial parameter set).
a_init = np.array(np.concatenate((field_params['pa'], [plate_scale.value], ap.flatten(), bp.flatten(),\
                                  radec_est['ra_est'], radec_est['dec_est']))) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
measured = np.concatenate((observed_xy_overlap['x'], observed_xy_overlap['y']))
#pos = np.where(measured>180.)
#measured[pos] -= 360.
#pos = np.where(measured<-180.)
#measured[pos] += 360.

result, _ = ls.solve(measured, a_init, max_iteration=100, epsilon=1.e-8)

## pa should be a positive value between 0 and 360.
#if result[3] < 0:
#    result[3] = -result[3]
#    result[2] = result[2] + 180.0
#
#if result[2] > 360.0 or result[2] < 0.0:
#    result[2] = result[2]%360.0
# Out:
# 2021-07-25 20:09:34,502  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:09:34,600  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 0.223510)
# 2021-07-25 20:09:44,738  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:09:44,841  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 0.019734)
# 2021-07-25 20:09:54,968  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:09:55,070  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 0.006746)
# 2021-07-25 20:10:05,261  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:10:05,345  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 0.003948)
# 2021-07-25 20:10:15,565  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:10:15,664  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 0.002397)
# 2021-07-25 20:10:25,875  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:10:25,976  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 0.001374)
# 2021-07-25 20:10:36,220  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:10:36,323  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 0.000864)
# 2021-07-25 20:10:46,472  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:10:46,577  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 0.000501)
# 2021-07-25 20:10:56,716  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:10:56,817  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.000279)
# 2021-07-25 20:11:06,983  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:11:07,084  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.000158)
# 2021-07-25 20:11:17,195  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:11:17,296  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.000103)
# 2021-07-25 20:11:27,689  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:11:27,787  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.000069)
# 2021-07-25 20:11:37,940  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:11:38,038  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.000041)
# 2021-07-25 20:11:48,269  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:11:48,371  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.000066)
# 2021-07-25 20:11:58,528  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:11:58,629  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.000037)
# 2021-07-25 20:12:08,780  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:12:08,880  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000048)
# 2021-07-25 20:12:19,019  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:12:19,116  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000041)
# 2021-07-25 20:12:29,251  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:12:29,348  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.000010)
# 2021-07-25 20:12:39,485  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:12:39,583  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000034)
# 2021-07-25 20:12:49,732  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:12:49,830  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000026)
# 2021-07-25 20:12:59,983  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:13:00,081  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000023)
# 2021-07-25 20:13:10,236  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:13:10,334  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.000056)
# 2021-07-25 20:13:20,511  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:13:20,609  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000028)
# 2021-07-25 20:13:30,825  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:13:30,923  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000048)
# 2021-07-25 20:13:41,063  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:13:41,164  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000056)
# 2021-07-25 20:13:51,304  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:13:51,409  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.000031)
# 2021-07-25 20:14:01,660  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:14:01,762  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000101)
# 2021-07-25 20:14:11,912  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:14:12,014  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.000080)
# 2021-07-25 20:14:22,154  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:14:22,256  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.000032)
# 2021-07-25 20:14:32,436  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:14:32,539  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.000047)
# 2021-07-25 20:14:42,685  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:14:42,788  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000049)
# 2021-07-25 20:14:52,927  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:14:53,028  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000039)
# 2021-07-25 20:15:03,178  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:15:03,283  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000025)
# 2021-07-25 20:15:13,430  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:15:13,532  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000017)
# 2021-07-25 20:15:23,759  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:15:23,855  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000061)
# 2021-07-25 20:15:33,987  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:15:34,090  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000048)
# 2021-07-25 20:15:44,213  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:15:44,312  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000073)
# 2021-07-25 20:15:54,524  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:15:54,628  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000049)
# 2021-07-25 20:16:04,767  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:16:04,866  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000014)
# 2021-07-25 20:16:15,011  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:16:15,112  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000033)
# 2021-07-25 20:16:25,260  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:16:25,360  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.000070)
# 2021-07-25 20:16:35,484  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:16:35,586  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000045)
# 2021-07-25 20:16:45,722  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:16:45,818  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000055)
# 2021-07-25 20:16:55,954  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:16:56,056  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000040)
# 2021-07-25 20:17:06,202  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:17:06,303  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000014)
# 2021-07-25 20:17:16,452  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:17:16,553  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000041)
# 2021-07-25 20:17:26,728  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:17:26,827  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000026)
# 2021-07-25 20:17:36,952  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:17:37,051  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000039)
# 2021-07-25 20:17:47,187  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:17:47,286  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000047)
# 2021-07-25 20:17:57,425  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:17:57,534  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000022)
# 2021-07-25 20:18:08,630  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:18:08,741  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000068)
# 2021-07-25 20:18:19,787  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:18:19,879  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000071)
# 2021-07-25 20:18:30,921  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:18:31,015  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000023)
# 2021-07-25 20:18:42,126  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:18:42,218  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000023)
# 2021-07-25 20:18:53,264  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:18:53,358  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000024)
# 2021-07-25 20:19:04,422  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:19:04,514  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000033)
# 2021-07-25 20:19:15,574  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:19:15,667  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000034)
# 2021-07-25 20:19:26,725  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:19:26,818  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000039)
# 2021-07-25 20:19:37,886  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:19:37,980  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000031)
# 2021-07-25 20:19:49,048  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:19:49,140  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000057)
# 2021-07-25 20:20:00,213  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:20:00,307  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000037)
# 2021-07-25 20:20:11,370  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:20:11,464  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000028)
# 2021-07-25 20:20:22,535  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:20:22,627  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000047)
# 2021-07-25 20:20:33,699  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:20:33,792  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.000014)
# 2021-07-25 20:20:44,855  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:20:44,948  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.000035)
# 2021-07-25 20:20:56,008  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:20:56,102  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.000019)
# 2021-07-25 20:21:07,177  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:21:07,270  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.000012)
# 2021-07-25 20:21:18,342  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:21:18,436  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000033)
# 2021-07-25 20:21:29,506  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:21:29,600  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000026)
# 2021-07-25 20:21:40,675  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:21:40,768  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000039)
# 2021-07-25 20:21:51,828  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:21:51,921  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000027)
# 2021-07-25 20:22:02,996  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:22:03,090  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000018)
# 2021-07-25 20:22:14,158  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:22:14,252  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.000020)
# 2021-07-25 20:22:25,327  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:22:25,421  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000012)
# 2021-07-25 20:22:36,503  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:22:36,594  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.000035)
# 2021-07-25 20:22:47,656  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:22:47,749  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000057)
# 2021-07-25 20:22:58,819  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:22:58,912  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000018)
# 2021-07-25 20:23:10,037  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:23:10,131  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000037)
# 2021-07-25 20:23:21,168  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:23:21,261  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000029)
# 2021-07-25 20:23:32,305  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:23:32,399  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000049)
# 2021-07-25 20:23:43,445  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:23:43,537  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000034)
# 2021-07-25 20:23:54,590  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:23:54,684  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000032)
# 2021-07-25 20:24:05,742  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:24:05,835  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000016)
# 2021-07-25 20:24:16,881  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:24:16,974  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000014)
# 2021-07-25 20:24:28,035  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:24:28,128  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000044)
# 2021-07-25 20:24:39,182  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:24:39,276  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000019)
# 2021-07-25 20:24:50,328  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:24:50,422  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.000058)
# 2021-07-25 20:25:01,481  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:25:01,574  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000052)
# 2021-07-25 20:25:12,621  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:25:12,715  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000033)
# 2021-07-25 20:25:23,760  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:25:23,856  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000033)
# 2021-07-25 20:25:34,915  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:25:35,016  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000040)
# 2021-07-25 20:25:45,207  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:25:45,307  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000053)
# 2021-07-25 20:25:55,446  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:25:55,545  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.000098)
# 2021-07-25 20:26:05,701  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:26:05,801  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000044)
# 2021-07-25 20:26:15,944  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:26:16,046  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000038)
# 2021-07-25 20:26:26,186  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:26:26,288  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.000014)
# 2021-07-25 20:26:36,437  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:26:36,538  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000015)
# 2021-07-25 20:26:46,680  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:26:46,780  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000024)
# 2021-07-25 20:26:56,928  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:26:57,029  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000016)
# 2021-07-25 20:27:07,255  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-25 20:27:07,355  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000022)

# %% [markdown]
# ### Checking results

# %% [markdown]
# #### Preparation

# %%
n_fields = np.size(field_params)
n_objects = np.size(radec_est)
ra_ptgs = field_params['ra']
dec_ptgs= field_params['dec']
pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
    np.split(result, [n_fields, n_fields+1,\
                      n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                      n_fields+1+2*(dim_sip+1)**2+n_objects])

# %% [markdown]
# #### Scale (deg/pix)

# %%
scale
# Out:
# array([0.00011773])

# %% [markdown]
# #### Object positions

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='Initial guess')
plt.scatter(ra_objs, dec_objs, marker='.', label='Final estimation')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Object positions')
plt.legend()

# %% [markdown]
# #### AP/BP matrices (must be scaled as described in the model function)

# %%
np.reshape(ap, (dim_sip+1, dim_sip+1))
# Out:
# array([[-3.21675404e-13, -2.41056742e-13, -1.24066180e-02,
#          1.99022099e-03, -1.48099304e-02],
#        [-4.17308974e-14,  5.74290090e-02, -1.93116675e-03,
#          5.24775177e-02, -4.85865410e-13],
#        [-2.17384352e-02,  1.23361963e-02, -2.24738694e-02,
#          2.72711318e-13, -5.74812571e-13],
#        [-3.40716239e-03,  7.80619670e-02,  2.50967111e-13,
#         -6.01440680e-13,  9.80956954e-14],
#        [-2.60907422e-02,  1.25503571e-13, -8.85097234e-14,
#         -3.85670758e-14,  2.38141523e-14]])

# %%
np.reshape(bp, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 4.00152106e-14,  1.93353737e-13, -9.12122177e-02,
#         -1.50516636e-03, -1.27513119e-01],
#        [-4.12061216e-15, -1.99944244e-02, -1.14009223e-02,
#         -3.37843572e-02, -4.06316997e-16],
#        [ 3.07113547e-02, -1.21572622e-02, -2.68999876e-02,
#          9.50460549e-15, -4.72654150e-16],
#        [ 8.18813043e-04, -1.45057744e-02, -3.28966367e-15,
#          1.25640574e-14, -8.45125870e-17],
#        [ 4.05184100e-02,  2.90973875e-15,  1.98677492e-15,
#         -6.29587854e-15,  8.48738846e-16]])

# %% [markdown]
# #### Position difference

# %%
from astropy.coordinates import SkyCoord

distlist = []
dralist  = []
ddeclist = []
for i in range(0, np.size(ra_objs)):
    c1 = SkyCoord(ra_objs[i]*u.deg, dec_objs[i]*u.deg)
    c2 = SkyCoord(true_radec_overlap['ra'][i]*u.deg, true_radec_overlap['dec'][i]*u.deg)
    distlist.append(c1.separation(c2).arcsec)
    dra, ddec = c2.spherical_offsets_to(c1)
    dralist.append(dra.to(u.arcsec).value)
    ddeclist.append(ddec.to(u.arcsec).value)
distlist = np.array(distlist)
dralist  = np.array(dralist)
ddeclist = np.array(ddeclist)

# %%
#plt.hist(np.log10(distlist))
plt.hist(distlist)
plt.xlabel("Residual (arcsec)")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %%
plt.scatter(dralist, ddeclist)
plt.xlabel('dRA (arcsec)')
plt.ylabel('dDec (arcsec)')
plt.xlim([-0.03, 0.03])
plt.ylim([-0.03, 0.03])
# Out:
# (-0.03, 0.03)

# %% [markdown]
# #### Residual in focal-plane positions

# %%
ret = model(result, field_params['ra'], field_params['dec'], n_fields, n_objects, dim_sip, observed_xy_overlap)
dx = ret[0:900] - observed_xy_overlap['x']
dy = ret[900:1800] - observed_xy_overlap['y']
#plt.scatter(observed_xy_overlap['x'], observed_xy_overlap['y'], marker='+')
#plt.scatter(ret[0:900], ret[900:1800], marker='x')
plt.scatter(dx, dy, marker='x')
plt.xlabel('dx (pix)')
plt.ylabel('dy (pix)')
plt.xlim([-0.2, 0.2])
plt.ylim([-0.2, 0.2])
# Out:
# (-0.2, 0.2)
