# %% [markdown]
# # Case7-challenge00

# %% [markdown]
# In this note, we estimate the field parameters and sky coordinates of objects from the observed positions on the focal plane and pointing information. The data is the updated version of case7. The pointing positions are fixed as constants in this note. The SIP-convention distortion is considered in this note.

# %% [markdown]
# ## Preparation

# %% [markdown]
# At first, we add the analysis directry to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# Next, we load the data.

# %%
import astropy.io.ascii as asc
import astropy.units as u

objects = asc.read('case7_challenge_00.txt') #consists of x (um), y (um), catalog_id, ra (deg), dec (deg), and field.
pointings = asc.read('case7_challenge_00_pointing.txt') # consists of field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# We convert the units of x and y from um to pix with assuming the pixel size to be 15 um.

# %%
pix_size = 15.*u.um
objects['x'] = (objects['x']/pix_size).si
objects['y'] = (objects['y']/pix_size).si
# objects: x (px), y (px), catalog_id, ra (deg), dec (deg), and field.
# pointings: field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# Then, we change the ids for easy handling.

# %%
from astropy.table import unique
import numpy as np

ids = unique(objects, keys='catalog_id')['catalog_id']
objects.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(objects['catalog_id']==ids[i])
    objects['id'][pos] = i

objects.remove_column('catalog_id')
objects.rename_column('id', 'catalog_id')

# %% [markdown]
# Here, we make some arrays for further analysis. One new array is true_radec which stores true ra/dec values. Duplicated information (rows for the same object) is removed, and the rows are sorted with object ids. Another new array is observed_xy. It contains field ids, observed x/y positions on the focal plane, catalog ids, and estimated ra/dec values instead of true ra/dec values. The estimated ra/dec values are initialized to be zero at this moment.

# %%
true_radec = objects['catalog_id', 'ra', 'dec'].copy()
true_radec.sort('catalog_id')
true_radec = unique(true_radec, keys='catalog_id') # consists of catalog_id, ra (deg), and dec (deg).

observed_xy = objects['field', 'x', 'y', 'catalog_id', 'ra', 'dec'].copy()
observed_xy.rename_column('ra', 'ra_est')
observed_xy.rename_column('dec', 'dec_est')
# observed_xy will have field, x (px), y (px), catalog_id, and estimated ra/dec (deg).

# initializing ra_est and dec_est
observed_xy['ra_est']  = 0.0
observed_xy['dec_est'] = 0.0

# %% [markdown]
# In addition, we make another array which stores field parameters. The plate scale is assumed to be the same value for all plates. At this time, an approximated value is stored in a variable (plate_scale).

# %%
field_params = pointings.copy() # field, ra (deg), dec (deg), and pa (deg).
plate_scale = 8.e-6*u.deg*(pix_size/u.um).si # in deg/pix

# %% [markdown]
# Let's check the object distribution on sky.

# %%
import matplotlib.pylab as plt
import numpy as np

color = ['red', 'blue', 'green', 'orange']

for i in range(0, np.max(field_params['field'])+1):
    pos = np.where(objects['field']==i)
    plt.scatter(objects['ra'][pos], objects['dec'][pos], marker='o', facecolor='None', edgecolor=color[i], s=10*i+10)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# We can see that the data consists of four regions and that the overlapped region has a size of about a 1/4 FoV.

# %% [markdown]
# We select the objects in the overlapped region for further analysis.

# %%
true_radec_overlap = true_radec.copy()
observed_xy_overlap = observed_xy.copy()
for cid in true_radec['catalog_id']:
    if np.count_nonzero(observed_xy['catalog_id']==cid)!=4:
        pos = np.where(true_radec_overlap['catalog_id']==cid)[0]
        true_radec_overlap.remove_rows(pos)
        pos = np.where(observed_xy_overlap['catalog_id']==cid)[0]
        observed_xy_overlap.remove_rows(pos)

# %% [markdown]
# Let's check the distribution of the selected objects.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='o', facecolor='None', edgecolor='orange')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# These objects will be used for the following analysis.

# %% [markdown]
# We again modify the catalog id for easy handling.

# %%
ids = unique(true_radec_overlap, keys='catalog_id')['catalog_id']
true_radec_overlap.add_column(-1, name='id')
observed_xy_overlap.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(true_radec_overlap['catalog_id']==ids[i])
    true_radec_overlap['id'][pos] = i
    pos = np.where(observed_xy_overlap['catalog_id']==ids[i])
    observed_xy_overlap['id'][pos] = i

true_radec_overlap.remove_column('catalog_id')
true_radec_overlap.rename_column('id', 'catalog_id')
observed_xy_overlap.remove_column('catalog_id')
observed_xy_overlap.rename_column('id', 'catalog_id')

# %% [markdown]
# ## First guess of the positions

# %% [markdown]
# At first, we define a wcs constructor.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip
import astropy.units as u

def wcs(ra_ptg, dec_ptg, pa_ptg, scale, a=None, b=None, ap=None, bp=None):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale, scale])
    w.wcs.crval=[ra_ptg, dec_ptg]
    w.wcs.ctype=["RA---TAN-SIP", "DEC--TAN-SIP"]
    w.wcs.pc=[[np.cos(pa_ptg*u.deg), -np.sin(pa_ptg*u.deg)],
              [np.sin(pa_ptg*u.deg), np.cos(pa_ptg*u.deg)]]
#    if a is not None and b is not None:
    w.sip = Sip(a, b, ap, bp, [0, 0])
    
    return w

# %% [markdown]
# Then, we estimate the sky coordinates from the observed focal-plane positions and (approximated) field parameters.

# %%
for i in range(0, np.size(field_params)):
    fp = field_params[i]
    w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale.value)
    pos = np.where(observed_xy_overlap['field']==fp['field'])
    ret = w.all_pix2world(np.concatenate(([observed_xy_overlap[pos]['x']], [observed_xy_overlap[pos]['y']])).T, 0)
    observed_xy_overlap['ra_est'][pos]  = ret[:, 0]
    observed_xy_overlap['dec_est'][pos] = ret[:, 1]

# %% [markdown]
# Let's check the true positions and estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(observed_xy_overlap['ra_est'], observed_xy_overlap['dec_est'], marker='+', label='Estimated')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# Here, there are four estimated positions for each object. We take their mean values as the first-guess positions and store them in radec_est array.

# %%
from astropy.table import Table

radec_est = Table(names=['catalog_id', 'ra_est', 'dec_est'],\
           units=[None, u.deg, u.deg],\
           dtype=['int64', 'float64', 'float64'])

cat_ids = unique(observed_xy_overlap, 'catalog_id')['catalog_id']

for i in cat_ids:
    pos = np.where(observed_xy_overlap['catalog_id'] == i)
    ra = np.mean(observed_xy_overlap[pos]['ra_est'])*u.deg
    dec = np.mean(observed_xy_overlap[pos]['dec_est'])*u.deg
    radec_est.add_row([i, ra, dec])

# %% [markdown]
# Let's check the estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='First guess')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# ## Parameter adjustment

# %% [markdown]
# At first, we define a function which calculates x/y positions from the ra/dec values estimated above and the field/catalog ids.

# %%
def xy_calculator(observed_xy, field_params, plate_scale, ap, bp, radec_info):
    # observed_xy:  consists of field, x (px), y (px), catalog_id, ra_est (deg), and dec_est(deg).
    # field_params: consists of field, ra (deg), dec (deg), and pa (deg).
    # radec_info:   consists of catalog_id, ra_est (deg), and dec_est (deg).

    observed_xy_cp = observed_xy.copy()
    observed_xy_cp.rename_column('x', 'x_est')
    observed_xy_cp.rename_column('y', 'y_est')
    observed_xy_cp['x_est']   = None
    observed_xy_cp['y_est']   = None
    observed_xy_cp['ra_est']  = None
    observed_xy_cp['dec_est'] = None

    for i in range(0, np.size(radec_info)):
        pos = np.where(observed_xy_cp['catalog_id']==radec_info[i]['catalog_id'])
        observed_xy_cp['ra_est'][pos]  = radec_info[i]['ra_est']
        observed_xy_cp['dec_est'][pos] = radec_info[i]['dec_est']
    
    for i in range(0, np.size(field_params)):
        fp = field_params[i]
        w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale, ap=ap, bp=bp)
        pos = np.where(observed_xy_cp['field']==fp['field'])
        radec0 = np.concatenate(([observed_xy_cp[pos]['ra_est']], [observed_xy_cp[pos]['dec_est']])).T
        ret = w.sip_foc2pix(w.wcs_world2pix(radec0, 0)-w.wcs.crpix, 0)
        observed_xy_cp['x_est'][pos] = ret[:, 0]
        observed_xy_cp['y_est'][pos] = ret[:, 1]

    return observed_xy_cp['x_est', 'y_est']

# %% [markdown]
# Then, we define a model function to be used in the least-square calculation.

# %%
def model(params, ra_ptgs, dec_ptgs, n_fields, n_objects, dim_sip, observed_xy):
    # params = (pa_ptg..., scale, a..., b..., ra_obj..., dec_obj)
    pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
        np.split(params, [n_fields, n_fields+1,\
                          n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                          n_fields+1+2*(dim_sip+1)**2+n_objects])
    
    field_params = Table(data=[ra_ptgs, dec_ptgs, pa_ptgs, -np.ones(shape=(np.size(ra_ptgs)))],\
                         names=['ra', 'dec', 'pa', 'field'],\
                         units=[u.deg, u.deg, u.deg, None],\
                         dtype=['float64', 'float64', 'float64', 'int64'])
    
    ap_matrix = np.reshape(ap, (dim_sip+1, dim_sip+1))
    bp_matrix = np.reshape(bp, (dim_sip+1, dim_sip+1))
    
    mns = np.concatenate(((0, 1), np.arange(dim_sip+1, 2*(dim_sip)+1)))    
    for mn in mns:
        for m in range(np.max([0, mn-dim_sip]), np.min([mn+1, dim_sip+1])):
            n = mn - m
            ap_matrix[m, n] = 0
            bp_matrix[m, n] = 0

    m, n = np.indices((dim_sip+1, dim_sip+1))
    mn = m + n
    ap_matrix = ap_matrix * (1.e-3**mn)
    bp_matrix = bp_matrix * (1.e-3**mn)
    
    radec_info = Table(data=[ra_objs, dec_objs, -np.ones(shape=(np.size(ra_objs)))],\
                       names=['ra_est', 'dec_est', 'catalog_id'],\
                       units=[u.deg, u.deg, None],\
                       dtype=['float64', 'float64', 'int64'])
    
    field_params['field'] = np.arange(0, np.size(field_params))
    radec_info['catalog_id'] = np.arange(0, np.size(radec_info))
    
    ret = xy_calculator(observed_xy, field_params, scale[0], ap_matrix, bp_matrix, radec_info)

    return np.concatenate((ret['x_est'], ret['y_est']))

# %% [markdown]
# Next, we execute the least-square calculation to derive the field parameters and sky positions of the objects in the overlapped region.

# %%
from common.leastsquare import LeastSquare

dim_sip = 4
ap = np.zeros(shape=(dim_sip+1, dim_sip+1))
bp = np.zeros(shape=(dim_sip+1, dim_sip+1))

ls = LeastSquare(lambda a: model(a, field_params['ra'], field_params['dec'],\
                                 np.size(field_params), np.size(radec_est), dim_sip, observed_xy_overlap),\
                 np.size(observed_xy_overlap)*2)

# constructing a_init (initial parameter set).
a_init = np.array(np.concatenate((field_params['pa'], [plate_scale.value], ap.flatten(), bp.flatten(),\
                                  radec_est['ra_est'], radec_est['dec_est']))) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
measured = np.concatenate((observed_xy_overlap['x'], observed_xy_overlap['y']))
#pos = np.where(measured>180.)
#measured[pos] -= 360.
#pos = np.where(measured<-180.)
#measured[pos] += 360.

result, _ = ls.solve(measured, a_init, max_iteration=100, epsilon=1.e-8)

## pa should be a positive value between 0 and 360.
#if result[3] < 0:
#    result[3] = -result[3]
#    result[2] = result[2] + 180.0
#
#if result[2] > 360.0 or result[2] < 0.0:
#    result[2] = result[2]%360.0
# Out:
# 2021-07-24 11:18:50,331  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:18:50,489  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 0.226044)
# 2021-07-24 11:19:00,674  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:19:00,780  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 0.019529)
# 2021-07-24 11:19:10,912  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:19:11,017  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 0.007606)
# 2021-07-24 11:19:21,165  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:19:21,267  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 0.004479)
# 2021-07-24 11:19:31,423  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:19:31,532  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 0.002640)
# 2021-07-24 11:19:41,861  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:19:41,963  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 0.001602)
# 2021-07-24 11:19:52,109  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:19:52,211  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 0.000927)
# 2021-07-24 11:20:02,542  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:20:02,641  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 0.000589)
# 2021-07-24 11:20:12,851  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:20:12,950  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.000330)
# 2021-07-24 11:20:23,128  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:20:23,226  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.000229)
# 2021-07-24 11:20:33,655  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:20:33,760  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.000089)
# 2021-07-24 11:20:43,977  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:20:44,077  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.000080)
# 2021-07-24 11:20:54,186  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:20:54,291  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.000054)
# 2021-07-24 11:21:04,455  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:21:04,556  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.000065)
# 2021-07-24 11:21:14,673  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:21:14,774  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.000030)
# 2021-07-24 11:21:24,914  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:21:25,013  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000016)
# 2021-07-24 11:21:35,128  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:21:35,229  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000023)
# 2021-07-24 11:21:45,357  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:21:45,457  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.000019)
# 2021-07-24 11:21:55,566  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:21:55,665  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000012)
# 2021-07-24 11:22:05,804  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:22:05,905  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000048)
# 2021-07-24 11:22:16,016  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:22:16,117  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000057)
# 2021-07-24 11:22:26,218  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:22:26,318  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.000056)
# 2021-07-24 11:22:36,489  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:22:36,591  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000068)
# 2021-07-24 11:22:46,717  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:22:46,818  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000019)
# 2021-07-24 11:22:56,922  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:22:57,024  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000026)
# 2021-07-24 11:23:07,387  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:23:07,483  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.000010)
# 2021-07-24 11:23:17,577  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:23:17,677  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000016)
# 2021-07-24 11:23:27,761  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:23:27,845  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.000062)
# 2021-07-24 11:23:37,950  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:23:38,051  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.000046)
# 2021-07-24 11:23:48,181  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:23:48,279  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.000024)
# 2021-07-24 11:23:58,402  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:23:58,502  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000028)
# 2021-07-24 11:24:08,669  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:24:08,767  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000054)
# 2021-07-24 11:24:18,904  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:24:19,003  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000074)
# 2021-07-24 11:24:29,137  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:24:29,235  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000027)
# 2021-07-24 11:24:39,365  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:24:39,465  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000037)
# 2021-07-24 11:24:49,601  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:24:49,700  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000018)
# 2021-07-24 11:24:59,845  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:24:59,929  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000042)
# 2021-07-24 11:25:10,068  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:25:10,151  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000028)
# 2021-07-24 11:25:20,244  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:25:20,329  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000042)
# 2021-07-24 11:25:30,438  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:25:30,521  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000023)
# 2021-07-24 11:25:40,624  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:25:40,709  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.000018)
# 2021-07-24 11:25:50,837  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:25:50,920  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000021)
# 2021-07-24 11:26:01,090  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:26:01,191  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000017)
# 2021-07-24 11:26:11,349  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:26:11,448  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000017)
# 2021-07-24 11:26:21,605  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:26:21,707  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000023)
# 2021-07-24 11:26:31,861  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:26:31,960  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000032)
# 2021-07-24 11:26:42,117  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:26:42,217  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000040)
# 2021-07-24 11:26:52,360  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:26:52,463  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000030)
# 2021-07-24 11:27:02,627  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:27:02,726  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000060)
# 2021-07-24 11:27:12,875  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:27:12,980  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000063)
# 2021-07-24 11:27:23,130  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:27:23,232  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000038)
# 2021-07-24 11:27:33,444  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:27:33,545  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000013)
# 2021-07-24 11:27:43,676  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:27:43,775  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000016)
# 2021-07-24 11:27:53,907  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:27:54,011  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000048)
# 2021-07-24 11:28:04,162  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:28:04,263  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000035)
# 2021-07-24 11:28:14,409  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:28:14,513  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000020)
# 2021-07-24 11:28:24,655  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:28:24,755  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000033)
# 2021-07-24 11:28:35,020  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:28:35,124  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000069)
# 2021-07-24 11:28:45,270  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:28:45,371  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000036)
# 2021-07-24 11:28:55,524  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:28:55,633  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000028)
# 2021-07-24 11:29:05,793  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:29:05,901  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000040)
# 2021-07-24 11:29:16,057  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:29:16,161  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000011)
# 2021-07-24 11:29:26,292  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:29:26,395  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000020)
# 2021-07-24 11:29:36,562  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:29:36,664  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.000048)
# 2021-07-24 11:29:46,790  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:29:46,891  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.000029)
# 2021-07-24 11:29:57,222  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:29:57,324  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.000011)
# 2021-07-24 11:30:07,464  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:30:07,565  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.000031)
# 2021-07-24 11:30:17,698  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:30:17,800  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000085)
# 2021-07-24 11:30:27,933  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:30:28,035  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000059)
# 2021-07-24 11:30:38,172  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:30:38,273  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000062)
# 2021-07-24 11:30:48,576  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:30:48,675  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000078)
# 2021-07-24 11:30:58,801  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:30:58,900  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000033)
# 2021-07-24 11:31:09,239  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:31:09,339  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.000033)
# 2021-07-24 11:31:19,464  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:31:19,565  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000024)
# 2021-07-24 11:31:29,784  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:31:29,884  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.000038)
# 2021-07-24 11:31:40,011  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:31:40,111  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000019)
# 2021-07-24 11:31:50,232  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:31:50,337  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000068)
# 2021-07-24 11:32:00,465  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:32:00,566  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000079)
# 2021-07-24 11:32:10,680  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:32:10,781  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000058)
# 2021-07-24 11:32:20,896  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:32:20,995  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000024)
# 2021-07-24 11:32:31,169  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:32:31,269  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000025)
# 2021-07-24 11:32:41,502  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:32:41,604  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000030)
# 2021-07-24 11:32:51,723  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:32:51,822  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000053)
# 2021-07-24 11:33:01,929  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:33:02,038  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000041)
# 2021-07-24 11:33:12,192  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:33:12,293  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000046)
# 2021-07-24 11:33:22,410  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:33:22,511  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000049)
# 2021-07-24 11:33:32,617  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:33:32,718  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.000045)
# 2021-07-24 11:33:42,826  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:33:42,928  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000081)
# 2021-07-24 11:33:53,062  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:33:53,162  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000018)
# 2021-07-24 11:34:03,286  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:34:03,386  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000075)
# 2021-07-24 11:34:13,507  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:34:13,607  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000033)
# 2021-07-24 11:34:23,729  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:34:23,830  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000029)
# 2021-07-24 11:34:34,001  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:34:34,100  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.000017)
# 2021-07-24 11:34:44,221  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:34:44,320  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000036)
# 2021-07-24 11:34:54,450  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:34:54,549  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000066)
# 2021-07-24 11:35:04,679  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:35:04,777  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.000070)
# 2021-07-24 11:35:14,904  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:35:15,018  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000039)
# 2021-07-24 11:35:25,149  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:35:25,251  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000033)
# 2021-07-24 11:35:35,354  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:35:35,454  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000057)
# 2021-07-24 11:35:45,531  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 11:35:45,618  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000043)

# %% [markdown]
# ### Checking results

# %% [markdown]
# #### Preparation

# %%
n_fields = np.size(field_params)
n_objects = np.size(radec_est)
ra_ptgs = field_params['ra']
dec_ptgs= field_params['dec']
pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
    np.split(result, [n_fields, n_fields+1,\
                      n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                      n_fields+1+2*(dim_sip+1)**2+n_objects])

# %% [markdown]
# #### Scale (deg/pix)

# %%
scale
# Out:
# array([0.00011773])

# %% [markdown]
# #### Object positions

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='Initial guess')
plt.scatter(ra_objs, dec_objs, marker='.', label='Final estimation')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Object positions')
plt.legend()

# %% [markdown]
# #### AP/BP matrices (must be scaled as described in the model function)

# %%
np.reshape(ap, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 2.67646595e-13,  5.24039954e-14, -1.44685477e-02,
#          9.26848043e-03, -1.91604396e-02],
#        [ 5.60427782e-14,  5.87952335e-02,  2.95511497e-03,
#          5.22445007e-02,  5.58849003e-13],
#        [-2.06992118e-02,  1.54488608e-02, -2.41869288e-02,
#         -5.43450681e-13,  2.31993889e-13],
#        [-6.50989180e-03,  7.65909712e-02, -1.83827488e-13,
#          6.88390901e-13,  5.22645434e-13],
#        [-2.52737285e-02, -3.06025555e-12, -1.41691664e-12,
#          1.52674027e-12, -5.15818512e-13]])

# %%
np.reshape(bp, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 1.05948562e-12,  2.30684002e-13, -9.15712827e-02,
#         -4.05174186e-04, -1.28168355e-01],
#        [ 3.59772995e-15, -2.01644787e-02, -6.07151938e-03,
#         -3.64625086e-02,  1.21286114e-16],
#        [ 3.51252398e-02, -1.66483915e-02, -2.49980668e-02,
#         -1.65031916e-15,  4.93245819e-15],
#        [ 1.07724793e-02, -1.09926982e-02,  6.45353258e-15,
#         -1.45040495e-15, -7.77079876e-15],
#        [ 4.45333406e-02,  3.13458219e-15,  7.52509800e-15,
#         -5.89116025e-16,  4.09190856e-16]])

# %% [markdown]
# #### Position difference

# %%
from astropy.coordinates import SkyCoord

distlist = []
for i in range(0, np.size(ra_objs)):
    c1 = SkyCoord(ra_objs[i]*u.deg, dec_objs[i]*u.deg)
    c2 = SkyCoord(true_radec_overlap['ra'][i]*u.deg, true_radec_overlap['dec'][i]*u.deg)
    distlist.append(c1.separation(c2).arcsec)
distlist = np.array(distlist)

# %%
#plt.hist(np.log10(distlist))
plt.hist(distlist)
plt.xlabel("Residual (arcsec)")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %% [markdown]
# #### Residual in focal-plane positions

# %%
ret = model(result, field_params['ra'], field_params['dec'], n_fields, n_objects, dim_sip, observed_xy_overlap)
dx = ret[0:900] - observed_xy_overlap['x']
dy = ret[900:1800] - observed_xy_overlap['y']
#plt.scatter(observed_xy_overlap['x'], observed_xy_overlap['y'], marker='+')
#plt.scatter(ret[0:900], ret[900:1800], marker='x')
plt.scatter(dx, dy, marker='x')
plt.xlabel('dx (pix)')
plt.ylabel('dy (pix)')
plt.xlim([-0.2, 0.2])
plt.ylim([-0.2, 0.2])
# Out:
# (-0.2, 0.2)
