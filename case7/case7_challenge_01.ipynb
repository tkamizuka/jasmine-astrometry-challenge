# %% [markdown]
# # Case7-challenge01

# %% [markdown]
# In this note, we estimate the field parameters and sky coordinates of objects from the observed positions on the focal plane and pointing information. The data is the updated version of case7. The pointing positions are fixed as constants in this note. The SIP-convention distortion is considered in this note.

# %% [markdown]
# ## Preparation

# %% [markdown]
# At first, we add the analysis directry to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# Next, we load the data.

# %%
import astropy.io.ascii as asc
import astropy.units as u

objects = asc.read('case7_challenge_01.txt') #consists of x (um), y (um), catalog_id, ra (deg), dec (deg), and field.
pointings = asc.read('case7_challenge_01_pointing.txt') # consists of field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# We convert the units of x and y from um to pix with assuming the pixel size to be 15 um.

# %%
pix_size = 15.*u.um
objects['x'] = (objects['x']/pix_size).si
objects['y'] = (objects['y']/pix_size).si
# objects: x (px), y (px), catalog_id, ra (deg), dec (deg), and field.
# pointings: field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# Then, we change the ids for easy handling.

# %%
from astropy.table import unique
import numpy as np

ids = unique(objects, keys='catalog_id')['catalog_id']
objects.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(objects['catalog_id']==ids[i])
    objects['id'][pos] = i

objects.remove_column('catalog_id')
objects.rename_column('id', 'catalog_id')

# %% [markdown]
# Here, we make some arrays for further analysis. One new array is true_radec which stores true ra/dec values. Duplicated information (rows for the same object) is removed, and the rows are sorted with object ids. Another new array is observed_xy. It contains field ids, observed x/y positions on the focal plane, catalog ids, and estimated ra/dec values instead of true ra/dec values. The estimated ra/dec values are initialized to be zero at this moment.

# %%
true_radec = objects['catalog_id', 'ra', 'dec'].copy()
true_radec.sort('catalog_id')
true_radec = unique(true_radec, keys='catalog_id') # consists of catalog_id, ra (deg), and dec (deg).

observed_xy = objects['field', 'x', 'y', 'catalog_id', 'ra', 'dec'].copy()
observed_xy.rename_column('ra', 'ra_est')
observed_xy.rename_column('dec', 'dec_est')
# observed_xy will have field, x (px), y (px), catalog_id, and estimated ra/dec (deg).

# initializing ra_est and dec_est
observed_xy['ra_est']  = 0.0
observed_xy['dec_est'] = 0.0

# %% [markdown]
# In addition, we make another array which stores field parameters. The plate scale is assumed to be the same value for all plates. At this time, an approximated value is stored in a variable (plate_scale).

# %%
field_params = pointings.copy() # field, ra (deg), dec (deg), and pa (deg).
plate_scale = 8.e-6*u.deg*(pix_size/u.um).si # in deg/pix

# %% [markdown]
# Let's check the object distribution on sky.

# %%
import matplotlib.pylab as plt
import numpy as np

color = ['red', 'blue', 'green', 'orange']

for i in range(0, np.max(field_params['field'])+1):
    pos = np.where(objects['field']==i)
    plt.scatter(objects['ra'][pos], objects['dec'][pos], marker='o', facecolor='None', edgecolor=color[i], s=10*i+10)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# We can see that the data consists of four regions and that the overlapped region has a size of about a 1/4 FoV.

# %% [markdown]
# We select the objects in the overlapped region for further analysis.

# %%
true_radec_overlap = true_radec.copy()
observed_xy_overlap = observed_xy.copy()
for cid in true_radec['catalog_id']:
    if np.count_nonzero(observed_xy['catalog_id']==cid)!=4:
        pos = np.where(true_radec_overlap['catalog_id']==cid)[0]
        true_radec_overlap.remove_rows(pos)
        pos = np.where(observed_xy_overlap['catalog_id']==cid)[0]
        observed_xy_overlap.remove_rows(pos)

# %% [markdown]
# Let's check the distribution of the selected objects.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='o', facecolor='None', edgecolor='orange')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# These objects will be used for the following analysis.

# %% [markdown]
# We again modify the catalog id for easy handling.

# %%
ids = unique(true_radec_overlap, keys='catalog_id')['catalog_id']
true_radec_overlap.add_column(-1, name='id')
observed_xy_overlap.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(true_radec_overlap['catalog_id']==ids[i])
    true_radec_overlap['id'][pos] = i
    pos = np.where(observed_xy_overlap['catalog_id']==ids[i])
    observed_xy_overlap['id'][pos] = i

true_radec_overlap.remove_column('catalog_id')
true_radec_overlap.rename_column('id', 'catalog_id')
observed_xy_overlap.remove_column('catalog_id')
observed_xy_overlap.rename_column('id', 'catalog_id')

# %% [markdown]
# ## First guess of the positions

# %% [markdown]
# At first, we define a wcs constructor.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip
import astropy.units as u

def wcs(ra_ptg, dec_ptg, pa_ptg, scale, a=None, b=None, ap=None, bp=None):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale, scale])
    w.wcs.crval=[ra_ptg, dec_ptg]
    w.wcs.ctype=["RA---TAN-SIP", "DEC--TAN-SIP"]
    w.wcs.pc=[[np.cos(pa_ptg*u.deg), -np.sin(pa_ptg*u.deg)],
              [np.sin(pa_ptg*u.deg), np.cos(pa_ptg*u.deg)]]
#    if a is not None and b is not None:
    w.sip = Sip(a, b, ap, bp, [0, 0])
    
    return w

# %% [markdown]
# Then, we estimate the sky coordinates from the observed focal-plane positions and (approximated) field parameters.

# %%
for i in range(0, np.size(field_params)):
    fp = field_params[i]
    w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale.value)
    pos = np.where(observed_xy_overlap['field']==fp['field'])
    ret = w.all_pix2world(np.concatenate(([observed_xy_overlap[pos]['x']], [observed_xy_overlap[pos]['y']])).T, 0)
    observed_xy_overlap['ra_est'][pos]  = ret[:, 0]
    observed_xy_overlap['dec_est'][pos] = ret[:, 1]

# %% [markdown]
# Let's check the true positions and estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(observed_xy_overlap['ra_est'], observed_xy_overlap['dec_est'], marker='+', label='Estimated')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# Here, there are four estimated positions for each object. We take their mean values as the first-guess positions and store them in radec_est array.

# %%
from astropy.table import Table

radec_est = Table(names=['catalog_id', 'ra_est', 'dec_est'],\
           units=[None, u.deg, u.deg],\
           dtype=['int64', 'float64', 'float64'])

cat_ids = unique(observed_xy_overlap, 'catalog_id')['catalog_id']

for i in cat_ids:
    pos = np.where(observed_xy_overlap['catalog_id'] == i)
    ra = np.mean(observed_xy_overlap[pos]['ra_est'])*u.deg
    dec = np.mean(observed_xy_overlap[pos]['dec_est'])*u.deg
    radec_est.add_row([i, ra, dec])

# %% [markdown]
# Let's check the estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='First guess')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# ## Parameter adjustment

# %% [markdown]
# At first, we define a function which calculates x/y positions from the ra/dec values estimated above and the field/catalog ids.

# %%
def xy_calculator(observed_xy, field_params, plate_scale, ap, bp, radec_info):
    # observed_xy:  consists of field, x (px), y (px), catalog_id, ra_est (deg), and dec_est(deg).
    # field_params: consists of field, ra (deg), dec (deg), and pa (deg).
    # radec_info:   consists of catalog_id, ra_est (deg), and dec_est (deg).

    observed_xy_cp = observed_xy.copy()
    observed_xy_cp.rename_column('x', 'x_est')
    observed_xy_cp.rename_column('y', 'y_est')
    observed_xy_cp['x_est']   = None
    observed_xy_cp['y_est']   = None
    observed_xy_cp['ra_est']  = None
    observed_xy_cp['dec_est'] = None

    for i in range(0, np.size(radec_info)):
        pos = np.where(observed_xy_cp['catalog_id']==radec_info[i]['catalog_id'])
        observed_xy_cp['ra_est'][pos]  = radec_info[i]['ra_est']
        observed_xy_cp['dec_est'][pos] = radec_info[i]['dec_est']
    
    for i in range(0, np.size(field_params)):
        fp = field_params[i]
        w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale, ap=ap, bp=bp)
        pos = np.where(observed_xy_cp['field']==fp['field'])
        radec0 = np.concatenate(([observed_xy_cp[pos]['ra_est']], [observed_xy_cp[pos]['dec_est']])).T
        ret = w.sip_foc2pix(w.wcs_world2pix(radec0, 0)-w.wcs.crpix, 0)
        observed_xy_cp['x_est'][pos] = ret[:, 0]
        observed_xy_cp['y_est'][pos] = ret[:, 1]

    return observed_xy_cp['x_est', 'y_est']

# %% [markdown]
# Then, we define a model function to be used in the least-square calculation.

# %%
def model(params, ra_ptgs, dec_ptgs, n_fields, n_objects, dim_sip, observed_xy):
    # params = (pa_ptg..., scale, a..., b..., ra_obj..., dec_obj)
    pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
        np.split(params, [n_fields, n_fields+1,\
                          n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                          n_fields+1+2*(dim_sip+1)**2+n_objects])
    
    field_params = Table(data=[ra_ptgs, dec_ptgs, pa_ptgs, -np.ones(shape=(np.size(ra_ptgs)))],\
                         names=['ra', 'dec', 'pa', 'field'],\
                         units=[u.deg, u.deg, u.deg, None],\
                         dtype=['float64', 'float64', 'float64', 'int64'])
    
    ap_matrix = np.reshape(ap, (dim_sip+1, dim_sip+1))
    bp_matrix = np.reshape(bp, (dim_sip+1, dim_sip+1))
    
    mns = np.concatenate(((0, 1), np.arange(dim_sip+1, 2*(dim_sip)+1)))    
    for mn in mns:
        for m in range(np.max([0, mn-dim_sip]), np.min([mn+1, dim_sip+1])):
            n = mn - m
            ap_matrix[m, n] = 0
            bp_matrix[m, n] = 0

    m, n = np.indices((dim_sip+1, dim_sip+1))
    mn = m + n
    ap_matrix = ap_matrix * (1.e-3**mn)
    bp_matrix = bp_matrix * (1.e-3**mn)
    
    radec_info = Table(data=[ra_objs, dec_objs, -np.ones(shape=(np.size(ra_objs)))],\
                       names=['ra_est', 'dec_est', 'catalog_id'],\
                       units=[u.deg, u.deg, None],\
                       dtype=['float64', 'float64', 'int64'])
    
    field_params['field'] = np.arange(0, np.size(field_params))
    radec_info['catalog_id'] = np.arange(0, np.size(radec_info))
    
    ret = xy_calculator(observed_xy, field_params, scale[0], ap_matrix, bp_matrix, radec_info)

    return np.concatenate((ret['x_est'], ret['y_est']))

# %% [markdown]
# Next, we execute the least-square calculation to derive the field parameters and sky positions of the objects in the overlapped region.

# %%
from common.leastsquare import LeastSquare

dim_sip = 4
ap = np.zeros(shape=(dim_sip+1, dim_sip+1))
bp = np.zeros(shape=(dim_sip+1, dim_sip+1))

ls = LeastSquare(lambda a: model(a, field_params['ra'], field_params['dec'],\
                                 np.size(field_params), np.size(radec_est), dim_sip, observed_xy_overlap),\
                 np.size(observed_xy_overlap)*2)

# constructing a_init (initial parameter set).
a_init = np.array(np.concatenate((field_params['pa'], [plate_scale.value], ap.flatten(), bp.flatten(),\
                                  radec_est['ra_est'], radec_est['dec_est']))) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
measured = np.concatenate((observed_xy_overlap['x'], observed_xy_overlap['y']))
#pos = np.where(measured>180.)
#measured[pos] -= 360.
#pos = np.where(measured<-180.)
#measured[pos] += 360.

result, _ = ls.solve(measured, a_init, max_iteration=100, epsilon=1.e-8)

## pa should be a positive value between 0 and 360.
#if result[3] < 0:
#    result[3] = -result[3]
#    result[2] = result[2] + 180.0
#
#if result[2] > 360.0 or result[2] < 0.0:
#    result[2] = result[2]%360.0
# Out:
# 2021-07-24 14:19:34,795  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:19:35,050  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 0.210516)
# 2021-07-24 14:19:57,753  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:19:58,026  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 0.024243)
# 2021-07-24 14:20:20,734  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:20:21,003  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 0.010590)
# 2021-07-24 14:20:43,730  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:20:43,988  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 0.005638)
# 2021-07-24 14:21:06,670  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:21:06,943  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 0.001288)
# 2021-07-24 14:21:29,866  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:21:30,110  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 0.003242)
# 2021-07-24 14:21:52,779  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:21:53,024  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 0.000940)
# 2021-07-24 14:22:15,724  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:22:15,957  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 0.000518)
# 2021-07-24 14:22:38,625  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:22:38,867  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.001239)
# 2021-07-24 14:23:01,473  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:23:01,709  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.000213)
# 2021-07-24 14:23:24,385  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:23:24,633  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.000301)
# 2021-07-24 14:23:47,309  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:23:47,575  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.000494)
# 2021-07-24 14:24:10,295  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:24:10,555  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.000817)
# 2021-07-24 14:24:33,248  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:24:33,502  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.000298)
# 2021-07-24 14:24:56,156  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:24:56,414  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.001200)
# 2021-07-24 14:25:19,155  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:25:19,424  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000894)
# 2021-07-24 14:25:42,041  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:25:42,300  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000719)
# 2021-07-24 14:26:04,987  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:26:05,244  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.001084)
# 2021-07-24 14:26:27,872  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:26:28,133  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000356)
# 2021-07-24 14:26:50,768  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:26:51,032  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000070)
# 2021-07-24 14:27:13,627  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:27:13,883  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000540)
# 2021-07-24 14:27:36,556  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:27:36,821  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.001249)
# 2021-07-24 14:27:59,456  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:27:59,708  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000373)
# 2021-07-24 14:28:22,393  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:28:22,660  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000783)
# 2021-07-24 14:28:45,280  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:28:45,529  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000307)
# 2021-07-24 14:29:08,140  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:29:08,389  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.001026)
# 2021-07-24 14:29:31,061  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:29:31,314  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000954)
# 2021-07-24 14:29:53,988  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:29:54,269  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.000459)
# 2021-07-24 14:30:16,910  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:30:17,170  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.000103)
# 2021-07-24 14:30:40,222  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:30:40,497  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.001139)
# 2021-07-24 14:31:03,072  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:31:03,327  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000715)
# 2021-07-24 14:31:25,884  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:31:26,139  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000040)
# 2021-07-24 14:31:48,849  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:31:49,106  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000183)
# 2021-07-24 14:32:11,791  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:32:12,047  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000167)
# 2021-07-24 14:32:34,774  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:32:35,047  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000023)
# 2021-07-24 14:32:57,657  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:32:57,910  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000701)
# 2021-07-24 14:33:20,528  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:33:20,810  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000220)
# 2021-07-24 14:33:43,482  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:33:43,741  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000321)
# 2021-07-24 14:34:06,401  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:34:06,653  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000565)
# 2021-07-24 14:34:29,296  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:34:29,556  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000437)
# 2021-07-24 14:34:52,201  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:34:52,472  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.002103)
# 2021-07-24 14:35:15,125  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:35:15,383  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000530)
# 2021-07-24 14:35:38,033  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:35:38,293  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000828)
# 2021-07-24 14:36:00,936  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:36:01,190  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000643)
# 2021-07-24 14:36:23,839  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:36:24,096  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000599)
# 2021-07-24 14:36:46,748  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:36:47,006  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000188)
# 2021-07-24 14:37:09,720  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:37:09,992  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000485)
# 2021-07-24 14:37:32,669  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:37:32,933  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000049)
# 2021-07-24 14:37:55,585  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:37:55,861  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000392)
# 2021-07-24 14:38:18,708  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:38:18,953  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000870)
# 2021-07-24 14:38:42,686  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:38:42,937  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000301)
# 2021-07-24 14:39:05,863  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:39:06,142  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000776)
# 2021-07-24 14:39:28,899  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:39:29,149  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000024)
# 2021-07-24 14:39:51,807  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:39:52,060  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000041)
# 2021-07-24 14:40:14,705  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:40:14,970  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000692)
# 2021-07-24 14:40:37,705  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:40:37,962  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000624)
# 2021-07-24 14:41:00,646  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:41:00,907  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000144)
# 2021-07-24 14:41:23,591  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:41:23,840  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000484)
# 2021-07-24 14:41:46,512  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:41:46,771  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000697)
# 2021-07-24 14:42:09,490  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:42:09,752  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000559)
# 2021-07-24 14:42:32,478  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:42:32,749  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000087)
# 2021-07-24 14:42:55,437  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:42:55,693  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000925)
# 2021-07-24 14:43:18,404  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:43:18,669  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000439)
# 2021-07-24 14:43:41,356  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:43:41,618  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.001027)
# 2021-07-24 14:44:04,336  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:44:04,598  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.000071)
# 2021-07-24 14:44:27,312  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:44:27,582  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.000973)
# 2021-07-24 14:44:50,302  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:44:50,566  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.000515)
# 2021-07-24 14:45:13,273  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:45:13,539  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000896)
# 2021-07-24 14:45:36,237  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:45:36,504  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000234)
# 2021-07-24 14:45:59,195  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:45:59,466  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000133)
# 2021-07-24 14:46:22,155  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:46:22,425  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000786)
# 2021-07-24 14:46:45,126  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:46:45,407  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000964)
# 2021-07-24 14:47:08,100  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:47:08,376  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.001345)
# 2021-07-24 14:47:31,085  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:47:31,354  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000200)
# 2021-07-24 14:47:54,035  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:47:54,313  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.001031)
# 2021-07-24 14:48:16,994  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:48:17,268  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000381)
# 2021-07-24 14:48:39,958  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:48:40,245  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000113)
# 2021-07-24 14:49:02,934  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:49:03,213  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000493)
# 2021-07-24 14:49:25,894  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:49:26,189  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000049)
# 2021-07-24 14:49:48,874  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:49:49,148  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000348)
# 2021-07-24 14:50:11,821  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:50:12,105  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000174)
# 2021-07-24 14:50:34,816  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:50:35,089  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000400)
# 2021-07-24 14:50:57,826  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:50:58,106  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000105)
# 2021-07-24 14:51:20,793  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:51:21,069  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000452)
# 2021-07-24 14:51:43,796  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:51:44,071  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000056)
# 2021-07-24 14:52:06,783  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:52:07,061  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000649)
# 2021-07-24 14:52:29,759  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:52:30,028  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.001194)
# 2021-07-24 14:52:52,717  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:52:52,999  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000383)
# 2021-07-24 14:53:15,703  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:53:15,964  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000475)
# 2021-07-24 14:53:38,662  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:53:38,928  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000074)
# 2021-07-24 14:54:01,640  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:54:01,903  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000524)
# 2021-07-24 14:54:24,590  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:54:24,855  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000749)
# 2021-07-24 14:54:47,530  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:54:47,793  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.001502)
# 2021-07-24 14:55:10,494  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:55:10,772  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000250)
# 2021-07-24 14:55:33,467  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:55:33,743  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000024)
# 2021-07-24 14:55:56,448  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:55:56,722  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.001155)
# 2021-07-24 14:56:19,423  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:56:19,697  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000240)
# 2021-07-24 14:56:42,375  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:56:42,648  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000353)
# 2021-07-24 14:57:05,315  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:57:05,586  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000724)
# 2021-07-24 14:57:28,358  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-24 14:57:28,633  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000560)

# %% [markdown]
# ### Checking results

# %% [markdown]
# #### Preparation

# %%
n_fields = np.size(field_params)
n_objects = np.size(radec_est)
ra_ptgs = field_params['ra']
dec_ptgs= field_params['dec']
pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
    np.split(result, [n_fields, n_fields+1,\
                      n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                      n_fields+1+2*(dim_sip+1)**2+n_objects])

# %% [markdown]
# #### Scale (deg/pix)

# %%
scale
# Out:
# array([0.00011773])

# %% [markdown]
# #### Object positions

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='Initial guess')
plt.scatter(ra_objs, dec_objs, marker='.', label='Final estimation')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Object positions')
plt.legend()

# %% [markdown]
# #### AP/BP matrices (must be scaled as described in the model function)

# %%
np.reshape(ap, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 2.27574952e-10,  1.40016462e-11,  1.40691683e-02,
#         -9.77483559e-03,  5.03337998e-03],
#        [-1.26219894e-12, -5.29159656e-02,  7.14471088e-03,
#         -5.44749335e-02, -9.20841018e-11],
#        [ 2.89240045e-02, -6.03259355e-03,  4.35624049e-02,
#         -2.49142855e-11,  4.53025758e-11],
#        [-2.72244441e-03, -5.93340429e-02,  2.66283186e-11,
#         -5.52308642e-11,  9.48032327e-12],
#        [ 3.86390603e-02,  1.89663573e-10, -3.95327639e-10,
#          3.65854744e-10, -7.07228458e-11]])

# %%
np.reshape(bp, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 2.66150181e-11,  1.77980830e-11, -2.94685618e-02,
#          2.75731236e-03, -4.08208652e-02],
#        [ 6.35594284e-13,  3.52590834e-02, -8.20787862e-03,
#          4.74932251e-02, -8.71875054e-13],
#        [-7.88264311e-02,  2.40531020e-03, -3.81191116e-02,
#         -5.52646302e-13,  1.31500854e-13],
#        [-1.07611147e-02,  3.96354458e-02, -1.07424078e-13,
#         -1.03911810e-12, -5.41957489e-13],
#        [-1.18730835e-01,  8.71933705e-13,  4.33176566e-13,
#          1.03904907e-12,  6.38650521e-13]])

# %% [markdown]
# #### Position difference

# %%
from astropy.coordinates import SkyCoord

distlist = []
for i in range(0, np.size(ra_objs)):
    c1 = SkyCoord(ra_objs[i]*u.deg, dec_objs[i]*u.deg)
    c2 = SkyCoord(true_radec_overlap['ra'][i]*u.deg, true_radec_overlap['dec'][i]*u.deg)
    distlist.append(c1.separation(c2).arcsec)
distlist = np.array(distlist)

# %%
#plt.hist(np.log10(distlist))
plt.hist(distlist)
plt.xlabel("Residual (arcsec)")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %% [markdown]
# #### Residual in focal-plane positions

# %%
ret = model(result, field_params['ra'], field_params['dec'], n_fields, n_objects, dim_sip, observed_xy_overlap)
dx = ret[0:int(ret.size*0.5)] - observed_xy_overlap['x']
dy = ret[int(ret.size*0.5):int(ret.size)] - observed_xy_overlap['y']
#plt.scatter(observed_xy_overlap['x'], observed_xy_overlap['y'], marker='+')
#plt.scatter(ret[0:900], ret[900:1800], marker='x')
plt.scatter(dx, dy, marker='x')
plt.xlabel('dx (pix)')
plt.ylabel('dy (pix)')
plt.xlim([-0.2, 0.2])
plt.ylim([-0.2, 0.2])
# Out:
# (-0.2, 0.2)

# %%
ret.size
# Out:
# 3008
