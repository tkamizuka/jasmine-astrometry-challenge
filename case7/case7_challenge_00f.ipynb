# %% [markdown]
# # Case7-challenge00f

# %% [markdown]
# In this note, we estimate the field parameters and sky coordinates of objects from the observed positions on the focal plane and pointing information. The pointing positions are not variables in this note. When they are treated as variables, they converge to strange values (see Case7-challenge00a). The SIP-convention distortion is considered in this note.

# %% [markdown]
# ## Preparation

# %% [markdown]
# At first, we add the analysis directry to the python path.

# %%
import sys
sys.path.append('/home/kamizuka/analysis')

# %% [markdown]
# Next, we load the data.

# %%
import astropy.io.ascii as asc
import astropy.units as u

objects = asc.read('case7_challenge_00.txt') #consists of x (um), y (um), catalog_id, ra (deg), dec (deg), and field.
pointings = asc.read('case7_challenge_00_pointing.txt') # consists of field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# We convert the units of x and y from um to pix with assuming the pixel size to be 15 um.

# %%
pix_size = 15.*u.um
objects['x'] = (objects['x']/pix_size).si
objects['y'] = (objects['y']/pix_size).si
# objects: x (px), y (px), catalog_id, ra (deg), dec (deg), and field.
# pointings: field, ra (deg), dec (deg), and pa (deg).

# %% [markdown]
# Then, we change the ids for easy handling.

# %%
from astropy.table import unique
import numpy as np

ids = unique(objects, keys='catalog_id')['catalog_id']
objects.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(objects['catalog_id']==ids[i])
    objects['id'][pos] = i

objects.remove_column('catalog_id')
objects.rename_column('id', 'catalog_id')

# %% [markdown]
# Here, we make some arrays for further analysis. One new array is true_radec which stores true ra/dec values. Duplicated information (rows for the same object) is removed, and the rows are sorted with object ids. Another new array is observed_xy. It contains field ids, observed x/y positions on the focal plane, catalog ids, and estimated ra/dec values instead of true ra/dec values. The estimated ra/dec values are initialized to be zero at this moment.

# %%
true_radec = objects['catalog_id', 'ra', 'dec'].copy()
true_radec.sort('catalog_id')
true_radec = unique(true_radec, keys='catalog_id') # consists of catalog_id, ra (deg), and dec (deg).

observed_xy = objects['field', 'x', 'y', 'catalog_id', 'ra', 'dec'].copy()
observed_xy.rename_column('ra', 'ra_est')
observed_xy.rename_column('dec', 'dec_est')
# observed_xy will have field, x (px), y (px), catalog_id, and estimated ra/dec (deg).

# initializing ra_est and dec_est
observed_xy['ra_est']  = 0.0
observed_xy['dec_est'] = 0.0

# %% [markdown]
# In addition, we make another array which stores field parameters. The plate scale is assumed to be the same value for all plates. At this time, an approximated value is stored in a variable (plate_scale).

# %%
field_params = pointings.copy() # field, ra (deg), dec (deg), and pa (deg).
field_params['pa'] -= 240.0 # offset?
plate_scale = 8.e-6*u.deg*(pix_size/u.um).si # in deg/pix

# %% [markdown]
# Let's check the object distribution on sky.

# %%
import matplotlib.pylab as plt
import numpy as np

color = ['red', 'blue', 'green', 'orange']

for i in range(0, np.max(field_params['field'])+1):
    pos = np.where(objects['field']==i)
    plt.scatter(objects['ra'][pos], objects['dec'][pos], marker='o', facecolor='None', edgecolor=color[i], s=10*i+10)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# We can see that the data consists of four regions and that the overlapped region has a size of about a 1/4 FoV.

# %% [markdown]
# We select the objects in the overlapped region for further analysis.

# %%
true_radec_overlap = true_radec.copy()
observed_xy_overlap = observed_xy.copy()
for cid in true_radec['catalog_id']:
    if np.count_nonzero(observed_xy['catalog_id']==cid)!=4:
        pos = np.where(true_radec_overlap['catalog_id']==cid)[0]
        true_radec_overlap.remove_rows(pos)
        pos = np.where(observed_xy_overlap['catalog_id']==cid)[0]
        observed_xy_overlap.remove_rows(pos)

# %% [markdown]
# Let's check the distribution of the selected objects.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='o', facecolor='None', edgecolor='orange')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
# Out:
# Text(0, 0.5, 'dec (deg)')

# %% [markdown]
# These objects will be used for the following analysis.

# %% [markdown]
# We again modify the catalog id for easy handling.

# %%
ids = unique(true_radec_overlap, keys='catalog_id')['catalog_id']
true_radec_overlap.add_column(-1, name='id')
observed_xy_overlap.add_column(-1, name='id')
for i in range(0, np.size(ids)):
    pos = np.where(true_radec_overlap['catalog_id']==ids[i])
    true_radec_overlap['id'][pos] = i
    pos = np.where(observed_xy_overlap['catalog_id']==ids[i])
    observed_xy_overlap['id'][pos] = i

true_radec_overlap.remove_column('catalog_id')
true_radec_overlap.rename_column('id', 'catalog_id')
observed_xy_overlap.remove_column('catalog_id')
observed_xy_overlap.rename_column('id', 'catalog_id')

# %% [markdown]
# ## First guess of the positions

# %% [markdown]
# At first, we define a wcs constructor.

# %%
from astropy.wcs import WCS
from astropy.wcs import Sip
import astropy.units as u

def wcs(ra_ptg, dec_ptg, pa_ptg, scale, a=None, b=None, ap=None, bp=None):
    w = WCS(naxis=2)
    w.wcs.crpix=[0,0]
    w.wcs.cdelt=np.array([-scale, scale])
    w.wcs.crval=[ra_ptg, dec_ptg]
    w.wcs.ctype=["RA---TAN-SIP", "DEC--TAN-SIP"]
    w.wcs.pc=[[ np.cos(pa_ptg*u.deg), np.sin(pa_ptg*u.deg)],
              [-np.sin(pa_ptg*u.deg), np.cos(pa_ptg*u.deg)]]
#    if a is not None and b is not None:
    w.sip = Sip(a, b, ap, bp, [0, 0])
    
    return w

# %% [markdown]
# Then, we estimate the sky coordinates from the observed focal-plane positions and (approximated) field parameters.

# %%
for i in range(0, np.size(field_params)):
    fp = field_params[i]
    w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale.value)
    pos = np.where(observed_xy_overlap['field']==fp['field'])
    ret = w.all_pix2world(np.concatenate(([observed_xy_overlap[pos]['x']], [observed_xy_overlap[pos]['y']])).T, 0)
    observed_xy_overlap['ra_est'][pos]  = ret[:, 0]
    observed_xy_overlap['dec_est'][pos] = ret[:, 1]

# %% [markdown]
# Let's check the true positions and estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(observed_xy_overlap['ra_est'], observed_xy_overlap['dec_est'], marker='+', label='Estimated')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# Here, there are four estimated positions for each object. We take their mean values as the first-guess positions and store them in radec_est array.

# %%
from astropy.table import Table

radec_est = Table(names=['catalog_id', 'ra_est', 'dec_est'],\
           units=[None, u.deg, u.deg],\
           dtype=['int64', 'float64', 'float64'])

cat_ids = unique(observed_xy_overlap, 'catalog_id')['catalog_id']

for i in cat_ids:
    pos = np.where(observed_xy_overlap['catalog_id'] == i)
    ra = np.mean(observed_xy_overlap[pos]['ra_est'])*u.deg
    dec = np.mean(observed_xy_overlap[pos]['dec_est'])*u.deg
    radec_est.add_row([i, ra, dec])

# %% [markdown]
# Let's check the estimated positions.

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='First guess')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.legend()

# %% [markdown]
# ## Parameter adjustment

# %% [markdown]
# At first, we define a function which calculates x/y positions from the ra/dec values estimated above and the field/catalog ids.

# %%
def xy_calculator(observed_xy, field_params, plate_scale, ap, bp, radec_info):
    # observed_xy:  consists of field, x (px), y (px), catalog_id, ra_est (deg), and dec_est(deg).
    # field_params: consists of field, ra (deg), dec (deg), and pa (deg).
    # radec_info:   consists of catalog_id, ra_est (deg), and dec_est (deg).

    observed_xy_cp = observed_xy.copy()
    observed_xy_cp.rename_column('x', 'x_est')
    observed_xy_cp.rename_column('y', 'y_est')
    observed_xy_cp['x_est']   = None
    observed_xy_cp['y_est']   = None
    observed_xy_cp['ra_est']  = None
    observed_xy_cp['dec_est'] = None

    for i in range(0, np.size(radec_info)):
        pos = np.where(observed_xy_cp['catalog_id']==radec_info[i]['catalog_id'])
        observed_xy_cp['ra_est'][pos]  = radec_info[i]['ra_est']
        observed_xy_cp['dec_est'][pos] = radec_info[i]['dec_est']
    
    for i in range(0, np.size(field_params)):
        fp = field_params[i]
        w = wcs(fp['ra'], fp['dec'], fp['pa'], plate_scale, ap=ap, bp=bp)
        pos = np.where(observed_xy_cp['field']==fp['field'])
        radec0 = np.concatenate(([observed_xy_cp[pos]['ra_est']], [observed_xy_cp[pos]['dec_est']])).T
        ret = w.sip_foc2pix(w.wcs_world2pix(radec0, 0)-w.wcs.crpix, 0)
        observed_xy_cp['x_est'][pos] = ret[:, 0]
        observed_xy_cp['y_est'][pos] = ret[:, 1]

    return observed_xy_cp['x_est', 'y_est']

# %% [markdown]
# Then, we define a model function to be used in the least-square calculation.

# %%
def model(params, ra_ptgs, dec_ptgs, n_fields, n_objects, dim_sip, observed_xy):
    # params = (pa_ptg..., scale, a..., b..., ra_obj..., dec_obj)
    pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
        np.split(params, [n_fields, n_fields+1,\
                          n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                          n_fields+1+2*(dim_sip+1)**2+n_objects])
    
    field_params = Table(data=[ra_ptgs, dec_ptgs, pa_ptgs, -np.ones(shape=(np.size(ra_ptgs)))],\
                         names=['ra', 'dec', 'pa', 'field'],\
                         units=[u.deg, u.deg, u.deg, None],\
                         dtype=['float64', 'float64', 'float64', 'int64'])
    
    ap_matrix = np.reshape(ap, (dim_sip+1, dim_sip+1))
    bp_matrix = np.reshape(bp, (dim_sip+1, dim_sip+1))
    
    mns = np.concatenate(((0, 1), np.arange(dim_sip+1, 2*(dim_sip)+1)))    
    for mn in mns:
        for m in range(np.max([0, mn-dim_sip]), np.min([mn+1, dim_sip+1])):
            n = mn - m
            ap_matrix[m, n] = 0
            bp_matrix[m, n] = 0

    m, n = np.indices((dim_sip+1, dim_sip+1))
    mn = m + n
    ap_matrix = ap_matrix * (1.e-3**mn)
    bp_matrix = bp_matrix * (1.e-3**mn)
    
    radec_info = Table(data=[ra_objs, dec_objs, -np.ones(shape=(np.size(ra_objs)))],\
                       names=['ra_est', 'dec_est', 'catalog_id'],\
                       units=[u.deg, u.deg, None],\
                       dtype=['float64', 'float64', 'int64'])
    
    field_params['field'] = np.arange(0, np.size(field_params))
    radec_info['catalog_id'] = np.arange(0, np.size(radec_info))
    
    ret = xy_calculator(observed_xy, field_params, scale[0], ap_matrix, bp_matrix, radec_info)

    return np.concatenate((ret['x_est'], ret['y_est']))

# %% [markdown]
# Next, we execute the least-square calculation to derive the field parameters and sky positions of the objects in the overlapped region.

# %%
from common.leastsquare import LeastSquare

dim_sip = 4
ap = np.zeros(shape=(dim_sip+1, dim_sip+1))
bp = np.zeros(shape=(dim_sip+1, dim_sip+1))

ls = LeastSquare(lambda a: model(a, field_params['ra'], field_params['dec'],\
                                 np.size(field_params), np.size(radec_est), dim_sip, observed_xy_overlap),\
                 np.size(observed_xy_overlap)*2)

# constructing a_init (initial parameter set).
a_init = np.array(np.concatenate((field_params['pa'], [plate_scale.value], ap.flatten(), bp.flatten(),\
                                  radec_est['ra_est'], radec_est['dec_est']))) # This must be an ndarray.

# constraining ra/dec values in 'observed' between -180 and 180 deg.
measured = np.concatenate((observed_xy_overlap['x'], observed_xy_overlap['y']))
#pos = np.where(measured>180.)
#measured[pos] -= 360.
#pos = np.where(measured<-180.)
#measured[pos] += 360.

result, _ = ls.solve(measured, a_init, max_iteration=100, epsilon=1.e-8)

## pa should be a positive value between 0 and 360.
#if result[3] < 0:
#    result[3] = -result[3]
#    result[2] = result[2] + 180.0
#
#if result[2] > 360.0 or result[2] < 0.0:
#    result[2] = result[2]%360.0
# Out:
# 2021-07-23 16:58:22,800  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 16:58:25,132  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 1, norm = 7.301667)
# 2021-07-23 16:58:48,038  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 16:58:50,260  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 2, norm = 0.197550)
# 2021-07-23 16:59:13,806  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 16:59:17,404  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 3, norm = 0.263955)
# 2021-07-23 16:59:41,638  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 16:59:45,472  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 4, norm = 0.063688)
# 2021-07-23 17:00:06,935  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:00:10,952  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 5, norm = 0.009717)
# 2021-07-23 17:00:30,034  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:00:33,472  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 6, norm = 0.002652)
# 2021-07-23 17:00:57,575  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:00:58,501  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 7, norm = 0.001681)
# 2021-07-23 17:01:19,021  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:01:21,160  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 8, norm = 0.000914)
# 2021-07-23 17:01:40,115  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:01:43,340  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 9, norm = 0.000712)
# 2021-07-23 17:02:07,042  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:02:10,712  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 10, norm = 0.000350)
# 2021-07-23 17:02:38,693  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:02:41,992  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 11, norm = 0.000160)
# 2021-07-23 17:02:58,238  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:03:00,301  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 12, norm = 0.000336)
# 2021-07-23 17:03:20,773  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:03:23,916  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 13, norm = 0.000167)
# 2021-07-23 17:03:40,050  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:03:44,564  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 14, norm = 0.000079)
# 2021-07-23 17:04:08,366  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:04:11,345  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 15, norm = 0.000094)
# 2021-07-23 17:04:30,911  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:04:33,312  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 16, norm = 0.000081)
# 2021-07-23 17:04:49,523  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:04:52,188  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 17, norm = 0.000197)
# 2021-07-23 17:05:08,382  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:05:10,824  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 18, norm = 0.000120)
# 2021-07-23 17:05:27,183  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:05:29,933  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 19, norm = 0.000192)
# 2021-07-23 17:05:45,998  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:05:49,608  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 20, norm = 0.000109)
# 2021-07-23 17:06:09,563  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:06:14,344  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 21, norm = 0.000151)
# 2021-07-23 17:06:31,123  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:06:34,824  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 22, norm = 0.000198)
# 2021-07-23 17:06:56,228  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:06:59,932  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 23, norm = 0.000085)
# 2021-07-23 17:07:16,063  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:07:19,852  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 24, norm = 0.000133)
# 2021-07-23 17:07:36,127  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:07:40,548  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 25, norm = 0.000047)
# 2021-07-23 17:07:55,911  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:07:58,708  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 26, norm = 0.000089)
# 2021-07-23 17:08:15,167  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:08:17,040  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 27, norm = 0.000310)
# 2021-07-23 17:08:39,084  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:08:41,964  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 28, norm = 0.000234)
# 2021-07-23 17:08:59,092  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:09:03,489  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 29, norm = 0.000079)
# 2021-07-23 17:09:19,847  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:09:22,973  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 30, norm = 0.000622)
# 2021-07-23 17:09:40,939  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:09:43,806  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 31, norm = 0.000501)
# 2021-07-23 17:10:00,126  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:10:02,880  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 32, norm = 0.000224)
# 2021-07-23 17:10:18,978  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:10:21,776  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 33, norm = 0.000096)
# 2021-07-23 17:10:40,666  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:10:44,669  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 34, norm = 0.000119)
# 2021-07-23 17:11:00,168  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:11:03,385  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 35, norm = 0.000151)
# 2021-07-23 17:11:20,766  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:11:23,652  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 36, norm = 0.000188)
# 2021-07-23 17:11:47,094  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:11:51,392  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 37, norm = 0.000149)
# 2021-07-23 17:12:07,182  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:12:10,932  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 38, norm = 0.000220)
# 2021-07-23 17:12:26,670  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:12:30,360  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 39, norm = 0.000181)
# 2021-07-23 17:12:45,854  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:12:47,608  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 40, norm = 0.000180)
# 2021-07-23 17:13:03,258  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:13:06,184  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 41, norm = 0.000338)
# 2021-07-23 17:13:21,782  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:13:23,565  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 42, norm = 0.000097)
# 2021-07-23 17:13:40,674  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:13:42,440  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 43, norm = 0.000080)
# 2021-07-23 17:13:58,202  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:13:59,989  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 44, norm = 0.000278)
# 2021-07-23 17:14:17,970  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:14:19,752  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 45, norm = 0.000285)
# 2021-07-23 17:14:35,559  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:14:36,469  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 46, norm = 0.000175)
# 2021-07-23 17:14:56,255  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:14:58,745  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 47, norm = 0.000079)
# 2021-07-23 17:15:14,102  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:15:16,433  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 48, norm = 0.000149)
# 2021-07-23 17:15:32,019  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:15:34,400  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 49, norm = 0.000083)
# 2021-07-23 17:15:49,794  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:15:52,100  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 50, norm = 0.000100)
# 2021-07-23 17:16:07,819  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:16:10,280  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 51, norm = 0.000120)
# 2021-07-23 17:16:36,574  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:16:38,148  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 52, norm = 0.000079)
# 2021-07-23 17:16:53,633  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:16:55,729  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 53, norm = 0.000256)
# 2021-07-23 17:17:11,202  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:17:14,072  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 54, norm = 0.000361)
# 2021-07-23 17:17:29,439  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:17:31,020  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 55, norm = 0.000166)
# 2021-07-23 17:17:51,854  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:17:53,312  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 56, norm = 0.000075)
# 2021-07-23 17:18:08,846  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:18:10,492  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 57, norm = 0.000251)
# 2021-07-23 17:18:25,874  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:18:27,980  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 58, norm = 0.000076)
# 2021-07-23 17:18:42,946  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:18:44,781  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 59, norm = 0.000054)
# 2021-07-23 17:19:00,087  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:19:02,440  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 60, norm = 0.000034)
# 2021-07-23 17:19:16,838  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:19:19,280  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 61, norm = 0.000063)
# 2021-07-23 17:19:34,482  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:19:36,416  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 62, norm = 0.000075)
# 2021-07-23 17:19:51,306  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:19:53,685  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 63, norm = 0.000345)
# 2021-07-23 17:20:08,642  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:20:11,184  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 64, norm = 0.000275)
# 2021-07-23 17:20:26,254  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:20:28,609  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 65, norm = 0.000124)
# 2021-07-23 17:20:43,878  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:20:45,880  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 66, norm = 0.000098)
# 2021-07-23 17:21:00,826  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:21:02,341  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 67, norm = 0.000293)
# 2021-07-23 17:21:17,714  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:21:20,520  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 68, norm = 0.000109)
# 2021-07-23 17:21:45,614  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:21:47,576  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 69, norm = 0.000208)
# 2021-07-23 17:22:02,914  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:22:04,804  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 70, norm = 0.000193)
# 2021-07-23 17:22:20,226  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:22:22,800  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 71, norm = 0.000225)
# 2021-07-23 17:22:37,862  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:22:40,944  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 72, norm = 0.000112)
# 2021-07-23 17:22:55,519  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:22:58,501  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 73, norm = 0.000051)
# 2021-07-23 17:23:13,678  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:23:16,161  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 74, norm = 0.000185)
# 2021-07-23 17:23:31,418  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:23:32,940  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 75, norm = 0.000102)
# 2021-07-23 17:23:48,290  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:23:50,281  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 76, norm = 0.000062)
# 2021-07-23 17:24:05,403  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:24:06,780  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 77, norm = 0.000239)
# 2021-07-23 17:24:24,139  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:24:25,596  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 78, norm = 0.000187)
# 2021-07-23 17:24:41,035  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:24:42,153  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 79, norm = 0.000131)
# 2021-07-23 17:24:57,398  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:24:59,260  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 80, norm = 0.000060)
# 2021-07-23 17:25:14,534  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:25:16,028  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 81, norm = 0.000024)
# 2021-07-23 17:25:31,054  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:25:34,156  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 82, norm = 0.000169)
# 2021-07-23 17:25:49,262  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:25:53,224  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 83, norm = 0.000068)
# 2021-07-23 17:26:08,022  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:26:10,432  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 84, norm = 0.000164)
# 2021-07-23 17:26:25,430  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:26:26,744  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 85, norm = 0.000096)
# 2021-07-23 17:26:41,970  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:26:43,948  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 86, norm = 0.000075)
# 2021-07-23 17:26:58,842  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:27:00,828  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 87, norm = 0.000074)
# 2021-07-23 17:27:16,419  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:27:17,569  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 88, norm = 0.000060)
# 2021-07-23 17:27:32,854  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:27:34,045  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 89, norm = 0.000127)
# 2021-07-23 17:27:49,290  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:27:51,604  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 90, norm = 0.000101)
# 2021-07-23 17:28:06,666  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:28:08,820  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 91, norm = 0.000179)
# 2021-07-23 17:28:23,994  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:28:26,520  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 92, norm = 0.000131)
# 2021-07-23 17:28:41,702  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:28:42,836  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 93, norm = 0.000162)
# 2021-07-23 17:28:58,178  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:28:59,948  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 94, norm = 0.000115)
# 2021-07-23 17:29:15,150  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:29:17,206  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 95, norm = 0.000041)
# 2021-07-23 17:29:31,650  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:29:34,400  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 96, norm = 0.000114)
# 2021-07-23 17:29:49,806  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:29:51,305  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 97, norm = 0.000161)
# 2021-07-23 17:30:06,470  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:30:09,365  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 98, norm = 0.000182)
# 2021-07-23 17:30:24,514  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:30:27,992  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 99, norm = 0.000055)
# 2021-07-23 17:30:43,283  WARNING  common.leastsquare : Cannot calculate inverse matrix. Calculate pseudo-inverse matrix instead.
# 2021-07-23 17:30:45,648  DEBUG  common.leastsquare : Solving with least square calculation (iteration = 100, norm = 0.000052)

# %% [markdown]
# ### Checking results

# %% [markdown]
# #### Preparation

# %%
n_fields = np.size(field_params)
n_objects = np.size(radec_est)
ra_ptgs = field_params['ra']
dec_ptgs= field_params['dec']
pa_ptgs, scale, ap, bp, ra_objs, dec_objs =\
    np.split(result, [n_fields, n_fields+1,\
                      n_fields+1+(dim_sip+1)**2, n_fields+1+2*(dim_sip+1)**2,\
                      n_fields+1+2*(dim_sip+1)**2+n_objects])

# %% [markdown]
# #### Scale (deg/pix)

# %%
scale
# Out:
# array([0.00011773])

# %% [markdown]
# #### Object positions

# %%
plt.scatter(true_radec_overlap['ra'], true_radec_overlap['dec'], marker='x', label='True')
plt.scatter(radec_est['ra_est'], radec_est['dec_est'], marker='+', label='Initial guess')
plt.scatter(ra_objs, dec_objs, marker='.', label='Final estimation')
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Object positions')
plt.legend()

# %% [markdown]
# #### AP/BP matrices (must be scaled as described in the model function)

# %%
np.reshape(ap, (dim_sip+1, dim_sip+1))
# Out:
# array([[ 1.35681453e-13, -1.49762208e-13, -3.95793941e-02,
#          8.87570854e-03,  9.33473041e-04],
#        [-1.99036372e-13,  4.26521407e-02, -5.03956191e-03,
#          4.30078478e-02, -2.79507349e-13],
#        [-1.05390651e-02,  9.61205313e-03, -9.84521319e-03,
#         -5.47122612e-13, -5.32934275e-12],
#        [-6.19814332e-03,  9.44073842e-02, -6.30090568e-13,
#          4.20365787e-13, -6.25947702e-14],
#        [-3.77553566e-02,  7.99414642e-12, -1.08686682e-12,
#         -3.77175659e-13,  1.70527036e-13]])

# %%
np.reshape(bp, (dim_sip+1, dim_sip+1))
# Out:
# array([[-6.14350364e-13,  1.87133966e-13, -9.84123179e-02,
#         -1.03662271e-02, -1.16267269e-01],
#        [ 3.99859063e-15, -1.57266688e-02, -3.46367192e-02,
#         -4.74011195e-02, -1.40578398e-14],
#        [ 1.74456532e-02, -8.43158153e-03, -5.16088311e-02,
#         -1.97968229e-14, -4.17821134e-15],
#        [-1.60009630e-02, -9.15804115e-05, -3.29348494e-15,
#         -3.36470124e-15, -6.87124977e-15],
#        [ 5.38683400e-02,  2.34869545e-15, -2.20225955e-14,
#         -3.58887322e-15, -3.27591570e-15]])

# %% [markdown]
# #### Position difference

# %%
from astropy.coordinates import SkyCoord

distlist = []
for i in range(0, np.size(ra_objs)):
    c1 = SkyCoord(ra_objs[i]*u.deg, dec_objs[i]*u.deg)
    c2 = SkyCoord(true_radec_overlap['ra'][i]*u.deg, true_radec_overlap['dec'][i]*u.deg)
    distlist.append(c1.separation(c2).arcsec)
distlist = np.array(distlist)

# %%
#plt.hist(np.log10(distlist))
plt.hist(distlist)
plt.xlabel("Residual (arcsec)")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %% [markdown]
# #### Residual in focal-plane positions

# %%
ret = model(result, field_params['ra'], field_params['dec'], n_fields, n_objects, dim_sip, observed_xy_overlap)
dx = ret[0:900] - observed_xy_overlap['x']
dy = ret[900:1800] - observed_xy_overlap['y']
#plt.scatter(observed_xy_overlap['x'], observed_xy_overlap['y'], marker='+')
#plt.scatter(ret[0:900], ret[900:1800], marker='x')
plt.scatter(dx, dy, marker='x')
plt.xlabel('dx (pix)')
plt.ylabel('dy (pix)')
plt.xlim([-0.2, 0.2])
plt.ylim([-0.2, 0.2])
# Out:
# (-0.2, 0.2)
